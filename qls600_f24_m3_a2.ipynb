# %% [markdown]
# <a href="https://colab.research.google.com/github/yueliyl/qls600/blob/main/qls600_f24_m3_a2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #QLS600 Fall 2024 Module 3 Assignment 2 - unsupervised learning of single-cell transcriptome data using NMF and ETM
#
# In this assignment, you will directly modify the code blocks as instructed below to implement and experiment non-negative matrix factorization (NMF) and embedded topic model (ETM) on a single-cell RNA-seq datasets.
#
# For the rest of the codeblocks, simply click through them **without making any change**. You need to read and understand each codeblock. But we will only grade the assigned code blocks and the desired outputs.
#
# You are recommended to run the code using Colab. By the default Colab connects to a CPU node. To speed up the training, you may connect with a T4 GPU by choosing 'Runtime' in the top menu and then clicking on 'Change runtime type' and choose 'T4 GPU'. Note that for free Google account, we can keep the notebook connected to a GPU for at most 12 hours. Nonetheless, all the training and inference required to complete this assignment can be done within 5 minutes even with a CPU.
#
# If you have a good GPU-equipped Windows or Mac computer, you may connect to Local Runtime:
#
# 1. Install Jupyter Package for Colab: in Terminal with bash shell, do
#
#   ```
#   pip install jupyter_http_over_ws
#   jupyter serverextension enable --py jupyter_http_over_ws
#   ```
#
# 2. In Terminal, start a Jupyter Notebook instance on your local machine:
# ```
# jupyter notebook --NotebookApp.allow_origin='https://colab.research.google.com' --port=8888 --no-browser
# ```
# Copy one of the URLs generated as a token. From my side, it looks like this `http://localhost:8888/?token=[long string]`
#
# 3. Connect to Local Runtime in Colab:
#   1. Open your Colab notebook and select Connect → Connect to local runtime.
#   2. When prompted with local URL, paste the token URL you got from step 2.
#
# After this setup, Colab will connect to the local Jupyter Notebook server, allowing you to utilize your local machine's resources while running the notebook on Google Colab's interface.
#
# In my experiments, I used a Macbook Pro with M1 Max and 64 GB RAM. The speed is comparable to the T4 GPU and much faster than the default CPU on Colab.

# %%
#@title Install scanpy for single-cell data analysis
# !pip install scanpy
# Out:
# Collecting scanpy
#   Downloading scanpy-1.10.4-py3-none-any.whl.metadata (9.3 kB)
# Collecting anndata>=0.8 (from scanpy)
#   Downloading anndata-0.11.1-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: h5py>=3.6 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.12.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.4.2)
# Collecting legacy-api-wrap>=1.4 (from scanpy)
#   Downloading legacy_api_wrap-1.4-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.8.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.4.2)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.60.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.26.4)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from scanpy) (24.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.10/dist-packages (from scanpy) (2.2.2)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.0.1)
# Collecting pynndescent>=0.5 (from scanpy)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: scikit-learn>=1.1 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.5.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.13.1)
# Requirement already satisfied: seaborn>=0.13 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.13.2)
# Collecting session-info (from scanpy)
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.14.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from scanpy) (4.66.6)
# Collecting umap-learn!=0.5.0,>=0.5 (from scanpy)
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Collecting array-api-compat!=1.5,>1.4 (from anndata>=0.8->scanpy)
#   Downloading array_api_compat-1.9.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anndata>=0.8->scanpy) (1.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.56->scanpy) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->scanpy) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->scanpy) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1->scanpy) (3.5.0)
# Collecting stdlib_list (from session-info->scanpy)
#   Downloading stdlib_list-0.11.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->scanpy) (1.16.0)
# Downloading scanpy-1.10.4-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 27.3 MB/s eta 0:00:00
# Downloading anndata-0.11.1-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 4.5 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.4-py3-none-any.whl (15 kB)
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.3 MB/s eta 0:00:00
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 5.1 MB/s eta 0:00:00
# Downloading array_api_compat-1.9.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.6 MB/s eta 0:00:00
# Downloading stdlib_list-0.11.0-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 7.5 MB/s eta 0:00:00
# Building wheels for collected packages: session-info
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8023 sha256=dda108fc8f3e2026e9b12aab630710d2ba0856cf094985d371821124dc47035b
#   Stored in directory: /root/.cache/pip/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
# Successfully built session-info
# Installing collected packages: stdlib_list, legacy-api-wrap, array-api-compat, session-info, pynndescent, anndata, umap-learn, scanpy
# Successfully installed anndata-0.11.1 array-api-compat-1.9.1 legacy-api-wrap-1.4 pynndescent-0.5.13 scanpy-1.10.4 session-info-1.0.0 stdlib_list-0.11.0 umap-learn-0.5.7

# %%
#@title Install igraph and louvain needed for clustering evaluation below
# !pip install python-igraph
# !pip install louvain
# Out:
# Collecting python-igraph
#   Downloading python_igraph-0.11.8-py3-none-any.whl.metadata (2.8 kB)
# Collecting igraph==0.11.8 (from python-igraph)
#   Downloading igraph-0.11.8-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting texttable>=1.6.2 (from igraph==0.11.8->python-igraph)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Downloading python_igraph-0.11.8-py3-none-any.whl (9.1 kB)
# Downloading igraph-0.11.8-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 39.2 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph, python-igraph
# Successfully installed igraph-0.11.8 python-igraph-0.11.8 texttable-1.7.0
# Collecting louvain
#   Downloading louvain-0.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: igraph<0.12,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from louvain) (0.11.8)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from igraph<0.12,>=0.10.0->louvain) (1.7.0)
# Downloading louvain-0.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.9 MB/s eta 0:00:00
# Installing collected packages: louvain
# Successfully installed louvain-0.8.2

# %%
#@title Import all required libraries for this assignment
import pickle
import numpy as np
import pandas as pd

import scanpy as sc
import anndata
import random

import torch
from torch import nn
from torch import optim
from torch.nn import functional as F

import os
import matplotlib.pyplot as plt

from matplotlib.patches import Patch
from seaborn import heatmap, lineplot, clustermap
import seaborn as sns
from sklearn.metrics import adjusted_rand_score
import igraph as ig
import louvain as lv

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
random.seed(10)

# %% [markdown]
# # Mouse Pancreas single-cell RNA-sequencing data
# The folder a4_data contains the single-cell Mouse Pancreas dataset obtained from Baron et al (2016) study. The dataset has 1886 cells measured over 4194 genes by scRNA-seq and were processed and filtered for the purpose of this assignment. Here are the individual files:
#
# * `MP.pickle`: The single-cell expression count matrix (matrix of integers) of dimension 1886 cells by 4194 genes plus 2 columns indicating the batch IDs and cell types
# * `MP_genes.pickle`: gene names for the 4194 genes
# * `sample_info.csv`: a 1886 by 3 information matrix with the rows as the1886 cells and columns for the cell IDs, batch IDs (not used in this assignment), and cell type labels
# * `cell_IDs.pkl`: cell IDs as a list of strings
#
# The code block below loads the scRNA-seq data into a Pandas DataFrame `df` as well as the M gene names `genes` using a Python library called `pickle`. It then reorders the rows and columns and save the final $N\times M$ matrix $X$ into a Numpy `ndarray` for our subsequent matrix factorization tasks.
#
# In addition, using `anndata` library we create an AnnData object called `mp_anndata`, which as the input ndarray matrix $X$ and the ground-truth cell type labels for the 1886 cells for evaluation purpose.

# %%
# If run on Colab cloud compute (default), uncomment this code
from google.colab import drive
drive.mount('/content/drive')

# change this to the path where a4_data is saved on your Google Drive
# !git clone https://github.com/yueliyl/qls600 /content/drive/MyDrive/qls600
filepath = "/content/drive/MyDrive/qls600/"

# If running on local runtime, uncomment this change the file path if needed
# filepath = "~/qls600/"
# filepath = os.path.expanduser(filepath)

# Extract to the current directory
import zipfile
with zipfile.ZipFile(filepath+'MP.pickle.zip', 'r') as zip_ref:
    zip_ref.extractall(filepath)

# mouse pancreas single-cell dataset
# read in data and cell type labels
with open(filepath+'MP.pickle', 'rb') as f:
    df = pickle.load(f)

with open(filepath+'MP_genes.pickle', 'rb') as f:
    genes = pickle.load(f)

df.set_index('Unnamed: 0', inplace=True)  # set first column (cell ID as the index column)
sample_id = pickle.load(open(filepath+'cell_IDs.pkl', 'rb'))
df = df.loc[list(sample_id), :]

X = df[genes].values  # extract the N x M cells-by-genes matrix

sample_info = pd.read_csv(filepath+'sample_info.csv')

mp_anndata = anndata.AnnData(X=X)

mp_anndata.obs['Celltype'] = sample_info['assigned_cluster'].values

N = X.shape[0]  # number of single-cell samples
K = 16  # number of topics
M = X.shape[1]  # number of genes

X_tensor = torch.from_numpy(np.array(X, dtype="float32"))
sums = X_tensor.sum(1).unsqueeze(1)
X_tensor_normalized = X_tensor / sums
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# fatal: destination path '/content/drive/MyDrive/qls600' already exists and is not an empty directory.

# %% [markdown]
# # Evaluating clustering by adjusted Rand Index
# Adjusted Rand Index (ARI) is a common metric used to evaluate the unsupervised clustering by comparing the consistency between the predicted clusters and the ground-truth clusters (i.e., cell type labels in this assignment).
#
# The function `evaluate_ari(cell_embed, adata)` below takes $N\times K$ input cell embedding `cell_embed` with $K$ as the embedding dimensions and the annotated cell label data as `adata`. It first runs UMAP to compute the distance between cells based on their embeddings and then run Louvain clustering using the cells-cells distance matrix from UMAP to cluster cells into groups defined by the resolution parameter (default: 0.15). Finally, it computes the ARI based on the Louvain clusters and the ground-truth cell type using `adjusted_rand_score` from `Scikit-learn`.
#
# We will be using `evaluate_ari` to evaluate the cell embedding quality by NMF and ETM.

# %%
def evaluate_ari(cell_embed, adata):
    """
        This function is used to evaluate ARI using the lower-dimensional embedding
        cell_embed of the single-cell data
        :param cell_embed: a NxK single-cell embedding generated from NMF or scETM
        :param adata: single-cell AnnData data object (default to to mp_anndata)
        :return: ARI score of the clustering results produced by Louvain
    """
    adata.obsm['cell_embed'] = cell_embed
    sc.pp.neighbors(adata, use_rep="cell_embed", n_neighbors=30)
    sc.tl.louvain(adata, resolution=0.15)
    ari = adjusted_rand_score(adata.obs['Celltype'], adata.obs['louvain'])
    return ari

# %% [markdown]
# # Task 1 (1 point) NMF with SSE loss
#
# Implement the NMF function `nmf_sse` based on Lecture 13 slide 19. A function header, Docstring, and function call have been written for you.
#
# Your implementation can be in either Numpy or PyTorch. The latter is much faster when running on a GPU.
#
# Note that the NMF takes an input matrix of dimension $M\times N$ with $M$ genes and $N$ samples whereas the input matrix $X$ is a $N\times M$ dimension. Also, the matrix $H$ is a $K\times N$ matrix where the `evaluate_ari(cell_embed, adata)` above expects the cell embedding to have dimension $N\times K$. So you will need to provide these functions with the transposed of $X$ and $H$, respectively.
#
# Besides returning the final matrices $W$ and $H$, save the mean squared error (MSE) $MSE = ||X-WH||_2^2/(N*M)$ and ARI at each iteration into a 3-column ndarray called `perf` with the first column as the iteration index and return `perf` as the third output from the function `nmf_sse`.
#
# Run your NMF for 100 iterations and return $W$, $H$, and `perf` for the following analyses. This should take less than 3 minutes depending on your local computer. This should takes less than a minute to finish.

# %%
#@title NMF with SSE loss function
def nmf_sse(X, K, adata=mp_anndata, niter=100):
    """
    NMF with sum of squared error loss as the objective
    :param X: M x N input matrix (numpy array)
    :param K: low rank
    :param adata: annotated X matrix with cluster labels for evaluating ARI
    :param niter: number of iterations to run
    :return:
        1. updated W and H that minimize sum of squared error ||X - WH||^2_F s.t. W,H>=0
        2. niter-by-3 tensor with iteration index, SSE, and ARI as the 3 columns
    """

    # Initialize W and H with random values, ensuring they're on the GPU if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    M, N = X.shape
    W = torch.rand(M, K, device=device)
    H = torch.rand(K, N, device=device)
    X = torch.from_numpy(np.array(X, dtype="float32"))

    # Ensure X, W, and H are on the correct device
    X = X.to(device)
    W = W.to(device)
    H = H.to(device)

    # Initialize performance tracking array
    perf = torch.zeros((niter, 3), dtype=torch.float32, device=device)

    # COMPLETE THIS FUNCTION


    return W.cpu().numpy(), H.cpu().numpy(), perf.cpu()

# %%
W_nmf_sse, H_nmf_sse, nmf_sse_perf = nmf_sse(X.T, K, niter=100)
# Out:
# Iter: 0 .. MSE: 31.0977 .. ARI: 0.0000
# Iter: 1 .. MSE: 3.9494 .. ARI: 0.1461
# Iter: 2 .. MSE: 3.4526 .. ARI: 0.1382
# Iter: 3 .. MSE: 3.0610 .. ARI: 0.1674
# Iter: 4 .. MSE: 2.9223 .. ARI: 0.1608
# Iter: 5 .. MSE: 2.8404 .. ARI: 0.1743
# Iter: 6 .. MSE: 2.7945 .. ARI: 0.1578
# Iter: 7 .. MSE: 2.7666 .. ARI: 0.2813
# Iter: 8 .. MSE: 2.7472 .. ARI: 0.1584
# Iter: 9 .. MSE: 2.7317 .. ARI: 0.1944
# Iter: 10 .. MSE: 2.7170 .. ARI: 0.1946
# Iter: 11 .. MSE: 2.6989 .. ARI: 0.3033
# Iter: 12 .. MSE: 2.6701 .. ARI: 0.5423
# Iter: 13 .. MSE: 2.6318 .. ARI: 0.5475
# Iter: 14 .. MSE: 2.5973 .. ARI: 0.3636
# Iter: 15 .. MSE: 2.5695 .. ARI: 0.2660
# Iter: 16 .. MSE: 2.5468 .. ARI: 0.3765
# Iter: 17 .. MSE: 2.5277 .. ARI: 0.3836
# Iter: 18 .. MSE: 2.5111 .. ARI: 0.3778
# Iter: 19 .. MSE: 2.4964 .. ARI: 0.3772
# Iter: 20 .. MSE: 2.4832 .. ARI: 0.3778
# Iter: 21 .. MSE: 2.4713 .. ARI: 0.3776
# Iter: 22 .. MSE: 2.4603 .. ARI: 0.3818
# Iter: 23 .. MSE: 2.4500 .. ARI: 0.4021
# Iter: 24 .. MSE: 2.4403 .. ARI: 0.3851
# Iter: 25 .. MSE: 2.4308 .. ARI: 0.3824
# Iter: 26 .. MSE: 2.4213 .. ARI: 0.3847
# Iter: 27 .. MSE: 2.4112 .. ARI: 0.4012
# Iter: 28 .. MSE: 2.4000 .. ARI: 0.3951
# Iter: 29 .. MSE: 2.3867 .. ARI: 0.3943
# Iter: 30 .. MSE: 2.3702 .. ARI: 0.4001
# Iter: 31 .. MSE: 2.3500 .. ARI: 0.4038
# Iter: 32 .. MSE: 2.3265 .. ARI: 0.5881
# Iter: 33 .. MSE: 2.3004 .. ARI: 0.4046
# Iter: 34 .. MSE: 2.2663 .. ARI: 0.4106
# Iter: 35 .. MSE: 2.2310 .. ARI: 0.4022
# Iter: 36 .. MSE: 2.2066 .. ARI: 0.4526
# Iter: 37 .. MSE: 2.1871 .. ARI: 0.5876
# Iter: 38 .. MSE: 2.1724 .. ARI: 0.5776
# Iter: 39 .. MSE: 2.1595 .. ARI: 0.4119
# Iter: 40 .. MSE: 2.1486 .. ARI: 0.6471
# Iter: 41 .. MSE: 2.1393 .. ARI: 0.4079
# Iter: 42 .. MSE: 2.1313 .. ARI: 0.4560
# Iter: 43 .. MSE: 2.1244 .. ARI: 0.4448
# Iter: 44 .. MSE: 2.1182 .. ARI: 0.4168
# Iter: 45 .. MSE: 2.1126 .. ARI: 0.4048
# Iter: 46 .. MSE: 2.1075 .. ARI: 0.5858
# Iter: 47 .. MSE: 2.1025 .. ARI: 0.4842
# Iter: 48 .. MSE: 2.0976 .. ARI: 0.5740
# Iter: 49 .. MSE: 2.0929 .. ARI: 0.5742
# Iter: 50 .. MSE: 2.0884 .. ARI: 0.4282
# Iter: 51 .. MSE: 2.0833 .. ARI: 0.5725
# Iter: 52 .. MSE: 2.0769 .. ARI: 0.5738
# Iter: 53 .. MSE: 2.0678 .. ARI: 0.3633
# Iter: 54 .. MSE: 2.0539 .. ARI: 0.6528
# Iter: 55 .. MSE: 2.0316 .. ARI: 0.5684
# Iter: 56 .. MSE: 1.9986 .. ARI: 0.5688
# Iter: 57 .. MSE: 1.9577 .. ARI: 0.4423
# Iter: 58 .. MSE: 1.9178 .. ARI: 0.4311
# Iter: 59 .. MSE: 1.8908 .. ARI: 0.3690
# Iter: 60 .. MSE: 1.8721 .. ARI: 0.4218
# Iter: 61 .. MSE: 1.8588 .. ARI: 0.4392
# Iter: 62 .. MSE: 1.8513 .. ARI: 0.4271
# Iter: 63 .. MSE: 1.8463 .. ARI: 0.4330
# Iter: 64 .. MSE: 1.8421 .. ARI: 0.4241
# Iter: 65 .. MSE: 1.8375 .. ARI: 0.4245
# Iter: 66 .. MSE: 1.8345 .. ARI: 0.3634
# Iter: 67 .. MSE: 1.8321 .. ARI: 0.4195
# Iter: 68 .. MSE: 1.8304 .. ARI: 0.3673
# Iter: 69 .. MSE: 1.8287 .. ARI: 0.3652
# Iter: 70 .. MSE: 1.8272 .. ARI: 0.3642
# Iter: 71 .. MSE: 1.8260 .. ARI: 0.3640
# Iter: 72 .. MSE: 1.8250 .. ARI: 0.3639
# Iter: 73 .. MSE: 1.8239 .. ARI: 0.3646
# Iter: 74 .. MSE: 1.8228 .. ARI: 0.3659
# Iter: 75 .. MSE: 1.8220 .. ARI: 0.3652
# Iter: 76 .. MSE: 1.8213 .. ARI: 0.3667
# Iter: 77 .. MSE: 1.8204 .. ARI: 0.3685
# Iter: 78 .. MSE: 1.8197 .. ARI: 0.4202
# Iter: 79 .. MSE: 1.8191 .. ARI: 0.3675
# Iter: 80 .. MSE: 1.8187 .. ARI: 0.3682
# Iter: 81 .. MSE: 1.8183 .. ARI: 0.3674
# Iter: 82 .. MSE: 1.8179 .. ARI: 0.3681
# Iter: 83 .. MSE: 1.8175 .. ARI: 0.3683
# Iter: 84 .. MSE: 1.8170 .. ARI: 0.3689
# Iter: 85 .. MSE: 1.8158 .. ARI: 0.3668
# Iter: 86 .. MSE: 1.8148 .. ARI: 0.4202
# Iter: 87 .. MSE: 1.8142 .. ARI: 0.4205
# Iter: 88 .. MSE: 1.8138 .. ARI: 0.4191
# Iter: 89 .. MSE: 1.8134 .. ARI: 0.4185
# Iter: 90 .. MSE: 1.8131 .. ARI: 0.4201
# Iter: 91 .. MSE: 1.8126 .. ARI: 0.4183
# Iter: 92 .. MSE: 1.8122 .. ARI: 0.4204
# Iter: 93 .. MSE: 1.8119 .. ARI: 0.4204
# Iter: 94 .. MSE: 1.8117 .. ARI: 0.4205
# Iter: 95 .. MSE: 1.8114 .. ARI: 0.4204
# Iter: 96 .. MSE: 1.8111 .. ARI: 0.4211
# Iter: 97 .. MSE: 1.8109 .. ARI: 0.4205
# Iter: 98 .. MSE: 1.8106 .. ARI: 0.4201
# Iter: 99 .. MSE: 1.8103 .. ARI: 0.4213

# %% [markdown]
# # Monitor training progress
# THe function called `monitor_perf` below is completed and provided to you. It displays the SSE and ARI at each iteration from the above NMF-SSE training. If your above NMF implementation is correct, you will observe that the SSE drops quite rapidly at the first few iterations and the ARI increases in a zigzag way because it is an independent metric from the training objective.
#
# Use plot below as your reference. Although you may see a different progress with different random initialization of $W$ and $H$, the behaviour of your implemented NMF model should be very similar and this is true for all of the following tasks.
#
# We are going to use `monitor_perf` to monitor the performances of the other two models that we are going to implement next.

# %%
#@title Monitor ARI and objective function
def monitor_perf(perf, objective, path=""):
    """
    :param perf: niter-by-3 ndarray with iteration index, objective function, and ARI as the 3 columns
    :param objective: 'SSE', 'Poisson', or 'NELBO'
    :param path: path to save the figure if not display to the screen
    :behaviour: display or save a 2-by-1 plot showing the progress of optimizing objective and ARI as
        a function of iterations
    """
    perf = pd.DataFrame(data=perf, columns=['Iter', objective, 'ARI'])
    fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, sharey=False)
    lineplot(data=perf, x="Iter", y=objective, ax=ax1)
    lineplot(data=perf, x="Iter", y="ARI", ax=ax2)
    if path == "":
        plt.show()
    else:
        plt.savefig(path)

monitor_perf(nmf_sse_perf, "MSE")

# %% [markdown]
# # Task 2 (2 points) NMF with log Poisson likelihood
# Implement the NMF function `nmf_psn` that maximizes the log Poisson likelihood w.r.t. $W$ and $H$ s.t. $W,H\ge0$ based on Lecture 13 slide 53.
#
# Your implementation can be in either Numpy or PyTorch. The latter is much faster when running on a GPU.
#
# Save the average log Poisson likelihood $(X\log WH - WH)/(N\times M)$ and ARI at each iteration.
#
# Note that because the NMF algorithm requires element-wise division, to avoid dividing by zeros, you can set the zero values to a small value like so: `np.where(A > 0, A, 1e-16)`.

# %%
#@title NMF Poisson likelihood
def nmf_psn(X, K, adata=mp_anndata, niter=100):
    """
    NMF with log Poisson likelihood as the objective
    :param X: M x N input matrix
    :param K: low rank
    :param adata: annotated X matrix with cluster labels for evaluating ARI
    :param niter: number of iterations to run
    :return:
        1. updated W and H that minimize log Poisson likelihood
        2. niter-by-3 tensor with iteration index, Loglik, and ARI as the 3 columns
    """
    # Initialize W and H with random values, ensuring they're on the GPU if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    M, N = X.shape
    W = torch.rand(M, K, device=device)
    H = torch.rand(K, N, device=device)
    X = torch.from_numpy(np.array(X, dtype="float32"))

    # Ensure X, W, and H are on the correct device
    X = X.to(device)
    W = W.to(device)
    H = H.to(device)

    # Initialize performance tracking array
    perf = torch.zeros((niter, 3), dtype=torch.float32, device=device)

    # COMPLETE THIS FUNCTION


    return W.cpu().numpy(), H.cpu().numpy(), perf.cpu()

# %% [markdown]
# Train your implemented NMF-Poisson

# %%
W_nmf_psn, H_nmf_psn, nmf_psn_perf = nmf_psn(X.T, K, niter=100)
# Out:
# Iter: 0 .. Loglik: -0.1650 .. ARI: 0.0000
# Iter: 1 .. Loglik: -0.1519 .. ARI: 0.1167
# Iter: 2 .. Loglik: -0.1311 .. ARI: 0.1327
# Iter: 3 .. Loglik: -0.1072 .. ARI: 0.1480
# Iter: 4 .. Loglik: -0.0854 .. ARI: 0.1508
# Iter: 5 .. Loglik: -0.0641 .. ARI: 0.4622
# Iter: 6 .. Loglik: -0.0439 .. ARI: 0.5602
# Iter: 7 .. Loglik: -0.0292 .. ARI: 0.5789
# Iter: 8 .. Loglik: -0.0206 .. ARI: 0.6202
# Iter: 9 .. Loglik: -0.0150 .. ARI: 0.6303
# Iter: 10 .. Loglik: -0.0106 .. ARI: 0.6318
# Iter: 11 .. Loglik: -0.0067 .. ARI: 0.6563
# Iter: 12 .. Loglik: -0.0029 .. ARI: 0.6553
# Iter: 13 .. Loglik: 0.0005 .. ARI: 0.8806
# Iter: 14 .. Loglik: 0.0032 .. ARI: 0.8291
# Iter: 15 .. Loglik: 0.0054 .. ARI: 0.8270
# Iter: 16 .. Loglik: 0.0072 .. ARI: 0.8254
# Iter: 17 .. Loglik: 0.0088 .. ARI: 0.8201
# Iter: 18 .. Loglik: 0.0102 .. ARI: 0.8239
# Iter: 19 .. Loglik: 0.0115 .. ARI: 0.8245
# Iter: 20 .. Loglik: 0.0126 .. ARI: 0.8697
# Iter: 21 .. Loglik: 0.0137 .. ARI: 0.8619
# Iter: 22 .. Loglik: 0.0146 .. ARI: 0.8952
# Iter: 23 .. Loglik: 0.0154 .. ARI: 0.6222
# Iter: 24 .. Loglik: 0.0160 .. ARI: 0.5994
# Iter: 25 .. Loglik: 0.0166 .. ARI: 0.6230
# Iter: 26 .. Loglik: 0.0171 .. ARI: 0.6171
# Iter: 27 .. Loglik: 0.0176 .. ARI: 0.6206
# Iter: 28 .. Loglik: 0.0181 .. ARI: 0.6137
# Iter: 29 .. Loglik: 0.0187 .. ARI: 0.6222
# Iter: 30 .. Loglik: 0.0190 .. ARI: 0.6233
# Iter: 31 .. Loglik: 0.0194 .. ARI: 0.6231
# Iter: 32 .. Loglik: 0.0196 .. ARI: 0.5918
# Iter: 33 .. Loglik: 0.0199 .. ARI: 0.5940
# Iter: 34 .. Loglik: 0.0201 .. ARI: 0.6221
# Iter: 35 .. Loglik: 0.0203 .. ARI: 0.5915
# Iter: 36 .. Loglik: 0.0205 .. ARI: 0.6208
# Iter: 37 .. Loglik: 0.0207 .. ARI: 0.5152
# Iter: 38 .. Loglik: 0.0209 .. ARI: 0.5840
# Iter: 39 .. Loglik: 0.0210 .. ARI: 0.6206
# Iter: 40 .. Loglik: 0.0212 .. ARI: 0.5833
# Iter: 41 .. Loglik: 0.0213 .. ARI: 0.5822
# Iter: 42 .. Loglik: 0.0214 .. ARI: 0.5836
# Iter: 43 .. Loglik: 0.0215 .. ARI: 0.5835
# Iter: 44 .. Loglik: 0.0216 .. ARI: 0.6209
# Iter: 45 .. Loglik: 0.0217 .. ARI: 0.6209
# Iter: 46 .. Loglik: 0.0218 .. ARI: 0.6243
# Iter: 47 .. Loglik: 0.0219 .. ARI: 0.5796
# Iter: 48 .. Loglik: 0.0220 .. ARI: 0.5799
# Iter: 49 .. Loglik: 0.0220 .. ARI: 0.5794
# Iter: 50 .. Loglik: 0.0221 .. ARI: 0.5904
# Iter: 51 .. Loglik: 0.0222 .. ARI: 0.6140
# Iter: 52 .. Loglik: 0.0222 .. ARI: 0.6154
# Iter: 53 .. Loglik: 0.0223 .. ARI: 0.6203
# Iter: 54 .. Loglik: 0.0223 .. ARI: 0.5855
# Iter: 55 .. Loglik: 0.0224 .. ARI: 0.5778
# Iter: 56 .. Loglik: 0.0224 .. ARI: 0.5849
# Iter: 57 .. Loglik: 0.0225 .. ARI: 0.6183
# Iter: 58 .. Loglik: 0.0225 .. ARI: 0.6190
# Iter: 59 .. Loglik: 0.0225 .. ARI: 0.5799
# Iter: 60 .. Loglik: 0.0226 .. ARI: 0.5776
# Iter: 61 .. Loglik: 0.0226 .. ARI: 0.6259
# Iter: 62 .. Loglik: 0.0227 .. ARI: 0.5750
# Iter: 63 .. Loglik: 0.0227 .. ARI: 0.5845
# Iter: 64 .. Loglik: 0.0227 .. ARI: 0.5784
# Iter: 65 .. Loglik: 0.0228 .. ARI: 0.5817
# Iter: 66 .. Loglik: 0.0228 .. ARI: 0.5771
# Iter: 67 .. Loglik: 0.0228 .. ARI: 0.5794
# Iter: 68 .. Loglik: 0.0229 .. ARI: 0.5773
# Iter: 69 .. Loglik: 0.0229 .. ARI: 0.5820
# Iter: 70 .. Loglik: 0.0229 .. ARI: 0.5791
# Iter: 71 .. Loglik: 0.0230 .. ARI: 0.5798
# Iter: 72 .. Loglik: 0.0230 .. ARI: 0.5568
# Iter: 73 .. Loglik: 0.0230 .. ARI: 0.5806
# Iter: 74 .. Loglik: 0.0231 .. ARI: 0.5807
# Iter: 75 .. Loglik: 0.0231 .. ARI: 0.6085
# Iter: 76 .. Loglik: 0.0231 .. ARI: 0.6088
# Iter: 77 .. Loglik: 0.0232 .. ARI: 0.6011
# Iter: 78 .. Loglik: 0.0232 .. ARI: 0.6075
# Iter: 79 .. Loglik: 0.0232 .. ARI: 0.6010
# Iter: 80 .. Loglik: 0.0233 .. ARI: 0.5988
# Iter: 81 .. Loglik: 0.0233 .. ARI: 0.6084
# Iter: 82 .. Loglik: 0.0233 .. ARI: 0.5984
# Iter: 83 .. Loglik: 0.0234 .. ARI: 0.5976
# Iter: 84 .. Loglik: 0.0234 .. ARI: 0.5524
# Iter: 85 .. Loglik: 0.0234 .. ARI: 0.5868
# Iter: 86 .. Loglik: 0.0234 .. ARI: 0.5873
# Iter: 87 .. Loglik: 0.0235 .. ARI: 0.5864
# Iter: 88 .. Loglik: 0.0235 .. ARI: 0.6076
# Iter: 89 .. Loglik: 0.0235 .. ARI: 0.6055
# Iter: 90 .. Loglik: 0.0235 .. ARI: 0.6055
# Iter: 91 .. Loglik: 0.0235 .. ARI: 0.6034
# Iter: 92 .. Loglik: 0.0236 .. ARI: 0.5846
# Iter: 93 .. Loglik: 0.0236 .. ARI: 0.5842
# Iter: 94 .. Loglik: 0.0236 .. ARI: 0.5794
# Iter: 95 .. Loglik: 0.0236 .. ARI: 0.5812
# Iter: 96 .. Loglik: 0.0237 .. ARI: 0.5836
# Iter: 97 .. Loglik: 0.0237 .. ARI: 0.5921
# Iter: 98 .. Loglik: 0.0237 .. ARI: 0.5863
# Iter: 99 .. Loglik: 0.0237 .. ARI: 0.5794

# %% [markdown]
# Check your implementation with `monitor_perf`.

# %%
monitor_perf(nmf_psn_perf, "Poisson")

# %% [markdown]
# # Compare NMF-SSE and NMF-Poisson
# Comparing the two models, we observe that the NMF-Poisson model led to higher ARI than the NMF-SSE model. This implies that the Poisson likelihood is a better objective function to model the discrete read counts of the scRNA-seq data than the SSE loss. The latter is equivalent to maximizing the log of Gaussian likelihood.

# %%
# compare NMF-SSE and NMF-Poisson
fig, ax = plt.subplots()
nmf_sse_perf_df = pd.DataFrame(data=nmf_sse_perf, columns=['Iter', "SSE", 'ARI'])
nmf_psn_perf_df = pd.DataFrame(data=nmf_psn_perf, columns=['Iter', "Poisson", 'ARI'])
ax.plot(nmf_sse_perf_df["Iter"], nmf_sse_perf_df["ARI"], color='blue', label='NMF-SSE')
ax.plot(nmf_psn_perf_df["Iter"], nmf_psn_perf_df["ARI"], color='red', label='NMF-PSN')
ax.legend()
plt.xlabel("Iteration");
plt.ylabel("ARI")
# Out:
# Text(0, 0.5, 'ARI')

# %% [markdown]
# # Embedding Topic Model (ETM)
# The codeblock bleow implements a simpler strip-down version of the scETM (Zhao et al, 2021). The code is the same as the original ETM implementation by Dieng et al (2020) that is available from \url{https://github.com/adjidieng/ETM}.

# %%
# @title ETM implementation (DO NOT MODIFY)
class ETM(nn.Module):
    def __init__(self, num_topics, vocab_size, t_hidden_size, rho_size, emsize,
                    theta_act, embeddings=None, train_embeddings=True, enc_drop=0.5):
        super(ETM, self).__init__()

        ## define hyperparameters
        self.num_topics = num_topics
        self.vocab_size = vocab_size
        self.t_hidden_size = t_hidden_size
        self.rho_size = rho_size
        self.enc_drop = enc_drop
        self.emsize = emsize
        self.t_drop = nn.Dropout(enc_drop)

        self.theta_act = self.get_activation(theta_act)

        self.train_embeddings = train_embeddings

        ## define the word embedding matrix \rho
        if self.train_embeddings:
            self.rho = nn.Parameter(torch.randn(vocab_size, rho_size)) # V x L
        else:
            self.rho = embeddings.clone().float().to(device) # V x L

        ## define the matrix containing the topic embeddings
        self.alphas = nn.Linear(rho_size, num_topics, bias=False)#nn.Parameter(torch.randn(rho_size, num_topics))

        ## define variational distribution for \theta_{1:D} via amortizartion
        self.q_theta = nn.Sequential(
                nn.Linear(vocab_size, t_hidden_size),
                self.theta_act,
                nn.Linear(t_hidden_size, t_hidden_size),
                self.theta_act,
            )
        self.mu_q_theta = nn.Linear(t_hidden_size, num_topics, bias=True)
        self.logsigma_q_theta = nn.Linear(t_hidden_size, num_topics, bias=True)

    def get_activation(self, act):
        if act == 'tanh':
            act = nn.Tanh()
        elif act == 'relu':
            act = nn.ReLU()
        elif act == 'softplus':
            act = nn.Softplus()
        elif act == 'rrelu':
            act = nn.RReLU()
        elif act == 'leakyrelu':
            act = nn.LeakyReLU()
        elif act == 'elu':
            act = nn.ELU()
        elif act == 'selu':
            act = nn.SELU()
        elif act == 'glu':
            act = nn.GLU()
        else:
            print('Defaulting to tanh activations...')
            act = nn.Tanh()
        return act

    # theta ~ mu + std N(0,1)
    def reparameterize(self, mu, logvar):
        """Returns a sample from a Gaussian distribution via reparameterization.
        """
        if self.training:
            std = torch.exp(0.5 * logvar)
            eps = torch.randn_like(std)
            return eps.mul_(std).add_(mu)
        else:
            return mu

    def encode(self, bows):
        """Returns paramters of the variational distribution for \theta.

        input: bows
                batch of bag-of-words...tensor of shape bsz x V
        output: mu_theta, log_sigma_theta
        """
        q_theta = self.q_theta(bows)
        if self.enc_drop > 0:
            q_theta = self.t_drop(q_theta)
        mu_theta = self.mu_q_theta(q_theta)
        logsigma_theta = self.logsigma_q_theta(q_theta)

        # KL[q(theta)||p(theta)] = lnq(theta) - lnp(theta)
        kl_theta = -0.5 * torch.sum(1 + logsigma_theta - mu_theta.pow(2) - logsigma_theta.exp(), dim=-1).mean()
        return mu_theta, logsigma_theta, kl_theta

    def get_beta(self):

        ## softmax over vocab dimension
        beta = F.softmax(self.alphas(self.rho), dim=0).transpose(1, 0)
        return beta

    def get_theta(self, normalized_bows):
        mu_theta, logsigma_theta, kld_theta = self.encode(normalized_bows)
        z = self.reparameterize(mu_theta, logsigma_theta)
        theta = F.softmax(z, dim=-1)
        return theta, kld_theta

    def decode(self, theta, beta):
        res = torch.mm(theta, beta)
        preds = torch.log(res+1e-6)
        return preds

    def forward(self, bows, normalized_bows, theta=None, aggregate=True):
        ## get \theta
        if theta is None:
            theta, kld_theta = self.get_theta(normalized_bows)
        else:
            kld_theta = None

        ## get \beta
        beta = self.get_beta()

        ## get prediction loss
        preds = self.decode(theta, beta)
        recon_loss = -(preds * bows).sum(1)
        if aggregate:
            recon_loss = recon_loss.mean()
        return recon_loss, kld_theta

# %% [markdown]
# The code to instantiate an ETM model object is already written for you with pre-specified hyperparameters (i.e., topic number, hidden size, learning rates, weight decay penalty, etc). You want to start with these settings. Once you get the model working, you may play around with these parameters to get higher ARI. But that is not mandatory.

# %%
model = ETM(num_topics=K,
            vocab_size=len(genes),
            t_hidden_size=256,
            rho_size=256,
            emsize=256,
            theta_act='relu',
            embeddings=None,
            train_embeddings=True,
            enc_drop=0.5).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1.2e-6)

# %% [markdown]
# # Task 3 (1 point) Implementing ETM
# Implement the wrapper function called `train_ETM` that uses the helper functions `train_ETM_helper` to train a ETM and another completed helper function called `get_theta` to compute cell embedding topic mixture $\mathbf{\theta}$. The latter two functions have been provided to you. **Do not modify them**.
#
# Note here that `get_theta` takes the normalized gene counts by the total count per cell stored in `X_tensor_normalized` as the input to the encoder neural network. The final reconstruction categorical likelihood is based on the unnormalized count data stored in `X_tensor`.
#
# PyTorch by default trace the error derivatives to calculate the gradient for backpropagation. When evaluating ARI, you want to turn off this automatic gradient trace by coding under the code block `with torch.no_grad()`.
#
# Here ARI is computed based on the Louvain clustering the cell embedding $\mathbf{\theta}$ against the ground-truth cell types stored in the `mp_anndata` object.

# %%
# train the VAE for one epoch
def train_ETM_helper(model, X_tensor, X_tensor_normalized):
    # initialize the model and loss
    model.train()
    optimizer.zero_grad()
    model.zero_grad()

    # forward and backward pass
    nll, kl_theta = model(X_tensor, X_tensor_normalized)
    loss = nll + kl_theta
    loss.backward()  # backprop gradients w.r.t. negative ELBO

    # clip gradients to 2.0 if it gets too large
    torch.nn.utils.clip_grad_norm_(model.parameters(), 2.0)

    # update model to minimize negative ELBO
    optimizer.step()

    return torch.sum(loss).item()

# get sample encoding theta from the trained encoder network
def get_theta(model, input_x):
    model.eval()
    with torch.no_grad():
        q_theta = model.q_theta(input_x)
        mu_theta = model.mu_q_theta(q_theta)
        theta = F.softmax(mu_theta, dim=-1)
        return theta

# %%
def train_ETM(model, X, adata=mp_anndata, niter=1000):
    """
        :param model: the ETM model object
        :param X: NxM raw read count matrix X
        :param adata: annotated single-cell data object with ground-truth cell type information for evaluation
        :param niter: maximum number of epochs
        :return:
            1. model: trained ETM model object
            2. perf: niter-by-3 ndarray with iteration index, NELBO, and ARI as the 3 columns
    """
    # Initialize W and H with random values, ensuring they're on the GPU if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    X_tensor = torch.from_numpy(np.array(X, dtype="float32"))
    sums = X_tensor.sum(1).unsqueeze(1)
    X_tensor_normalized = X_tensor / sums

    # Ensure X, W, and H are on the correct device
    X_tensor = X_tensor.to(device)
    X_tensor_normalized = X_tensor_normalized.to(device)

    # Initialize performance tracking array
    perf = torch.zeros((niter, 3), dtype=torch.float32, device=device)

    # WRITE YOUR CODE HERE


    return model, perf.cpu()

# %% [markdown]
# Training ETM requires many epochs because of the gradient descent updates with small learning rate. For debugging, start with 10 epochs. Once you confirm that your code is working, train ETM for 1000 epochs. Record the negative ELBO loss and ARI at each iteration and then use `monitor_perf` to display the training progress. With T4 enabled on Colab (or M1 Max on Mac), 1000 epochs take less than 5 minutes. CPU takes about 10 times longer.

# %%
model, scetm_perf = train_ETM(model, X, niter=1000)
# Out:
# Iter: 0 ..  NELBO: 9683.7588 .. ARI: 0.5554
# Iter: 1 ..  NELBO: 9650.5400 .. ARI: 0.5642
# Iter: 2 ..  NELBO: 9622.3818 .. ARI: 0.5648
# Iter: 3 ..  NELBO: 9589.9268 .. ARI: 0.8330
# Iter: 4 ..  NELBO: 9559.5889 .. ARI: 0.7560
# Iter: 5 ..  NELBO: 9525.7920 .. ARI: 0.7531
# Iter: 6 ..  NELBO: 9495.4941 .. ARI: 0.7517
# Iter: 7 ..  NELBO: 9465.7070 .. ARI: 0.7767
# Iter: 8 ..  NELBO: 9434.4072 .. ARI: 0.7783
# Iter: 9 ..  NELBO: 9403.2920 .. ARI: 0.7665
# Iter: 10 ..  NELBO: 9375.0752 .. ARI: 0.7636
# Iter: 11 ..  NELBO: 9340.6934 .. ARI: 0.7573
# Iter: 12 ..  NELBO: 9309.8838 .. ARI: 0.7542
# Iter: 13 ..  NELBO: 9276.7100 .. ARI: 0.5777
# Iter: 14 ..  NELBO: 9248.2949 .. ARI: 0.5761
# Iter: 15 ..  NELBO: 9212.1221 .. ARI: 0.5968
# Iter: 16 ..  NELBO: 9180.2881 .. ARI: 0.3984
# Iter: 17 ..  NELBO: 9147.7207 .. ARI: 0.4004
# Iter: 18 ..  NELBO: 9114.8242 .. ARI: 0.4413
# Iter: 19 ..  NELBO: 9083.9863 .. ARI: 0.3929
# Iter: 20 ..  NELBO: 9052.1934 .. ARI: 0.3843
# Iter: 21 ..  NELBO: 9016.9121 .. ARI: 0.4004
# Iter: 22 ..  NELBO: 8981.9453 .. ARI: 0.4032
# Iter: 23 ..  NELBO: 8951.3154 .. ARI: 0.3437
# Iter: 24 ..  NELBO: 8913.1787 .. ARI: 0.3350
# Iter: 25 ..  NELBO: 8883.1758 .. ARI: 0.3988
# Iter: 26 ..  NELBO: 8849.3789 .. ARI: 0.3929
# Iter: 27 ..  NELBO: 8819.4629 .. ARI: 0.4042
# Iter: 28 ..  NELBO: 8789.3682 .. ARI: 0.4237
# Iter: 29 ..  NELBO: 8761.2891 .. ARI: 0.3871
# Iter: 30 ..  NELBO: 8728.9736 .. ARI: 0.4152
# Iter: 31 ..  NELBO: 8703.5967 .. ARI: 0.3118
# Iter: 32 ..  NELBO: 8676.7285 .. ARI: 0.4630
# Iter: 33 ..  NELBO: 8658.7266 .. ARI: 0.4600
# Iter: 34 ..  NELBO: 8634.0352 .. ARI: 0.4120
# Iter: 35 ..  NELBO: 8604.0117 .. ARI: 0.4121
# Iter: 36 ..  NELBO: 8580.8916 .. ARI: 0.4901
# Iter: 37 ..  NELBO: 8558.9600 .. ARI: 0.4264
# Iter: 38 ..  NELBO: 8538.4385 .. ARI: 0.3974
# Iter: 39 ..  NELBO: 8520.8877 .. ARI: 0.4011
# Iter: 40 ..  NELBO: 8498.7676 .. ARI: 0.4011
# Iter: 41 ..  NELBO: 8481.7227 .. ARI: 0.4011
# Iter: 42 ..  NELBO: 8456.7432 .. ARI: 0.4013
# Iter: 43 ..  NELBO: 8441.9648 .. ARI: 0.3989
# Iter: 44 ..  NELBO: 8421.9355 .. ARI: 0.3971
# Iter: 45 ..  NELBO: 8402.9326 .. ARI: 0.3965
# Iter: 46 ..  NELBO: 8380.2871 .. ARI: 0.3962
# Iter: 47 ..  NELBO: 8358.1592 .. ARI: 0.3956
# Iter: 48 ..  NELBO: 8339.6895 .. ARI: 0.4389
# Iter: 49 ..  NELBO: 8320.5410 .. ARI: 0.3946
# Iter: 50 ..  NELBO: 8300.4053 .. ARI: 0.5745
# Iter: 51 ..  NELBO: 8280.7373 .. ARI: 0.5414
# Iter: 52 ..  NELBO: 8265.8623 .. ARI: 0.4384
# Iter: 53 ..  NELBO: 8246.2314 .. ARI: 0.5158
# Iter: 54 ..  NELBO: 8226.2422 .. ARI: 0.6210
# Iter: 55 ..  NELBO: 8209.1338 .. ARI: 0.6236
# Iter: 56 ..  NELBO: 8193.5322 .. ARI: 0.6392
# Iter: 57 ..  NELBO: 8175.8901 .. ARI: 0.3516
# Iter: 58 ..  NELBO: 8160.0410 .. ARI: 0.4355
# Iter: 59 ..  NELBO: 8142.1665 .. ARI: 0.3699
# Iter: 60 ..  NELBO: 8125.1621 .. ARI: 0.4091
# Iter: 61 ..  NELBO: 8107.3921 .. ARI: 0.3142
# Iter: 62 ..  NELBO: 8093.0898 .. ARI: 0.3019
# Iter: 63 ..  NELBO: 8079.0498 .. ARI: 0.2976
# Iter: 64 ..  NELBO: 8062.6113 .. ARI: 0.3101
# Iter: 65 ..  NELBO: 8044.9404 .. ARI: 0.3398
# Iter: 66 ..  NELBO: 8033.6846 .. ARI: 0.2186
# Iter: 67 ..  NELBO: 8017.5405 .. ARI: 0.1746
# Iter: 68 ..  NELBO: 8005.4150 .. ARI: 0.1809
# Iter: 69 ..  NELBO: 7993.8237 .. ARI: 0.1800
# Iter: 70 ..  NELBO: 7981.8184 .. ARI: 0.1374
# Iter: 71 ..  NELBO: 7970.8765 .. ARI: 0.1411
# Iter: 72 ..  NELBO: 7958.1729 .. ARI: 0.2831
# Iter: 73 ..  NELBO: 7949.3403 .. ARI: 0.1688
# Iter: 74 ..  NELBO: 7936.9106 .. ARI: 0.2649
# Iter: 75 ..  NELBO: 7927.6592 .. ARI: 0.2729
# Iter: 76 ..  NELBO: 7918.3496 .. ARI: 0.2411
# Iter: 77 ..  NELBO: 7908.3872 .. ARI: 0.2839
# Iter: 78 ..  NELBO: 7901.6934 .. ARI: 0.3709
# Iter: 79 ..  NELBO: 7891.4624 .. ARI: 0.3598
# Iter: 80 ..  NELBO: 7883.1118 .. ARI: 0.3334
# Iter: 81 ..  NELBO: 7874.6899 .. ARI: 0.3780
# Iter: 82 ..  NELBO: 7867.2749 .. ARI: 0.3228
# Iter: 83 ..  NELBO: 7858.5923 .. ARI: 0.3779
# Iter: 84 ..  NELBO: 7850.8882 .. ARI: 0.3593
# Iter: 85 ..  NELBO: 7844.6899 .. ARI: 0.3665
# Iter: 86 ..  NELBO: 7838.5444 .. ARI: 0.3791
# Iter: 87 ..  NELBO: 7830.7886 .. ARI: 0.2995
# Iter: 88 ..  NELBO: 7824.8633 .. ARI: 0.3366
# Iter: 89 ..  NELBO: 7818.1421 .. ARI: 0.3204
# Iter: 90 ..  NELBO: 7812.5869 .. ARI: 0.2882
# Iter: 91 ..  NELBO: 7808.3555 .. ARI: 0.3662
# Iter: 92 ..  NELBO: 7801.7759 .. ARI: 0.3672
# Iter: 93 ..  NELBO: 7796.5864 .. ARI: 0.2547
# Iter: 94 ..  NELBO: 7790.2222 .. ARI: 0.3708
# Iter: 95 ..  NELBO: 7785.3823 .. ARI: 0.3068
# Iter: 96 ..  NELBO: 7780.3701 .. ARI: 0.2220
# Iter: 97 ..  NELBO: 7776.7905 .. ARI: 0.3743
# Iter: 98 ..  NELBO: 7772.6748 .. ARI: 0.2340
# Iter: 99 ..  NELBO: 7768.3184 .. ARI: 0.3696
# Iter: 100 ..  NELBO: 7763.8481 .. ARI: 0.2284
# Iter: 101 ..  NELBO: 7759.3091 .. ARI: 0.2154
# Iter: 102 ..  NELBO: 7756.0190 .. ARI: 0.2138
# Iter: 103 ..  NELBO: 7751.7280 .. ARI: 0.1745
# Iter: 104 ..  NELBO: 7749.1665 .. ARI: 0.2057
# Iter: 105 ..  NELBO: 7745.7930 .. ARI: 0.3074
# Iter: 106 ..  NELBO: 7744.1460 .. ARI: 0.3129
# Iter: 107 ..  NELBO: 7739.1465 .. ARI: 0.2199
# Iter: 108 ..  NELBO: 7737.0225 .. ARI: 0.2362
# Iter: 109 ..  NELBO: 7733.4517 .. ARI: 0.2217
# Iter: 110 ..  NELBO: 7731.4683 .. ARI: 0.2065
# Iter: 111 ..  NELBO: 7728.5894 .. ARI: 0.2180
# Iter: 112 ..  NELBO: 7725.0864 .. ARI: 0.2413
# Iter: 113 ..  NELBO: 7724.2612 .. ARI: 0.2286
# Iter: 114 ..  NELBO: 7723.0908 .. ARI: 0.2216
# Iter: 115 ..  NELBO: 7719.5972 .. ARI: 0.2318
# Iter: 116 ..  NELBO: 7718.4595 .. ARI: 0.2133
# Iter: 117 ..  NELBO: 7717.3696 .. ARI: 0.2333
# Iter: 118 ..  NELBO: 7714.6255 .. ARI: 0.2405
# Iter: 119 ..  NELBO: 7712.2412 .. ARI: 0.2475
# Iter: 120 ..  NELBO: 7709.2705 .. ARI: 0.2542
# Iter: 121 ..  NELBO: 7708.9092 .. ARI: 0.2541
# Iter: 122 ..  NELBO: 7705.2192 .. ARI: 0.2506
# Iter: 123 ..  NELBO: 7702.9956 .. ARI: 0.2537
# Iter: 124 ..  NELBO: 7702.1470 .. ARI: 0.2334
# Iter: 125 ..  NELBO: 7700.0464 .. ARI: 0.2411
# Iter: 126 ..  NELBO: 7697.0371 .. ARI: 0.3531
# Iter: 127 ..  NELBO: 7695.1738 .. ARI: 0.2525
# Iter: 128 ..  NELBO: 7692.3125 .. ARI: 0.3535
# Iter: 129 ..  NELBO: 7690.8892 .. ARI: 0.3593
# Iter: 130 ..  NELBO: 7688.1816 .. ARI: 0.2554
# Iter: 131 ..  NELBO: 7686.0625 .. ARI: 0.3323
# Iter: 132 ..  NELBO: 7683.5078 .. ARI: 0.3089
# Iter: 133 ..  NELBO: 7680.0112 .. ARI: 0.3217
# Iter: 134 ..  NELBO: 7678.5332 .. ARI: 0.2893
# Iter: 135 ..  NELBO: 7673.6812 .. ARI: 0.3026
# Iter: 136 ..  NELBO: 7671.8848 .. ARI: 0.3029
# Iter: 137 ..  NELBO: 7668.5410 .. ARI: 0.3021
# Iter: 138 ..  NELBO: 7663.9653 .. ARI: 0.3100
# Iter: 139 ..  NELBO: 7661.2036 .. ARI: 0.3032
# Iter: 140 ..  NELBO: 7656.4404 .. ARI: 0.3035
# Iter: 141 ..  NELBO: 7653.2505 .. ARI: 0.3180
# Iter: 142 ..  NELBO: 7649.6470 .. ARI: 0.2972
# Iter: 143 ..  NELBO: 7646.6963 .. ARI: 0.3252
# Iter: 144 ..  NELBO: 7642.7119 .. ARI: 0.3255
# Iter: 145 ..  NELBO: 7637.3345 .. ARI: 0.3252
# Iter: 146 ..  NELBO: 7633.8652 .. ARI: 0.4248
# Iter: 147 ..  NELBO: 7629.8618 .. ARI: 0.3240
# Iter: 148 ..  NELBO: 7626.4453 .. ARI: 0.3240
# Iter: 149 ..  NELBO: 7622.4829 .. ARI: 0.3224
# Iter: 150 ..  NELBO: 7617.8828 .. ARI: 0.3233
# Iter: 151 ..  NELBO: 7614.2930 .. ARI: 0.3598
# Iter: 152 ..  NELBO: 7610.2119 .. ARI: 0.3605
# Iter: 153 ..  NELBO: 7606.5806 .. ARI: 0.3314
# Iter: 154 ..  NELBO: 7603.3423 .. ARI: 0.4244
# Iter: 155 ..  NELBO: 7598.3721 .. ARI: 0.4241
# Iter: 156 ..  NELBO: 7595.5581 .. ARI: 0.3809
# Iter: 157 ..  NELBO: 7590.2227 .. ARI: 0.3274
# Iter: 158 ..  NELBO: 7588.1860 .. ARI: 0.3537
# Iter: 159 ..  NELBO: 7583.9512 .. ARI: 0.3886
# Iter: 160 ..  NELBO: 7580.0073 .. ARI: 0.4010
# Iter: 161 ..  NELBO: 7576.2646 .. ARI: 0.4022
# Iter: 162 ..  NELBO: 7573.7617 .. ARI: 0.3586
# Iter: 163 ..  NELBO: 7569.0811 .. ARI: 0.3930
# Iter: 164 ..  NELBO: 7565.6958 .. ARI: 0.3600
# Iter: 165 ..  NELBO: 7561.7827 .. ARI: 0.3936
# Iter: 166 ..  NELBO: 7559.1489 .. ARI: 0.3711
# Iter: 167 ..  NELBO: 7554.8379 .. ARI: 0.3565
# Iter: 168 ..  NELBO: 7551.5508 .. ARI: 0.3036
# Iter: 169 ..  NELBO: 7548.4092 .. ARI: 0.3449
# Iter: 170 ..  NELBO: 7545.6621 .. ARI: 0.3913
# Iter: 171 ..  NELBO: 7540.7993 .. ARI: 0.3820
# Iter: 172 ..  NELBO: 7539.5977 .. ARI: 0.3898
# Iter: 173 ..  NELBO: 7535.8784 .. ARI: 0.4132
# Iter: 174 ..  NELBO: 7532.2578 .. ARI: 0.3206
# Iter: 175 ..  NELBO: 7530.4893 .. ARI: 0.4246
# Iter: 176 ..  NELBO: 7527.7686 .. ARI: 0.3993
# Iter: 177 ..  NELBO: 7524.1494 .. ARI: 0.3944
# Iter: 178 ..  NELBO: 7521.2900 .. ARI: 0.4254
# Iter: 179 ..  NELBO: 7519.8027 .. ARI: 0.4266
# Iter: 180 ..  NELBO: 7516.6880 .. ARI: 0.3943
# Iter: 181 ..  NELBO: 7514.4487 .. ARI: 0.3927
# Iter: 182 ..  NELBO: 7512.2432 .. ARI: 0.3930
# Iter: 183 ..  NELBO: 7509.5986 .. ARI: 0.3930
# Iter: 184 ..  NELBO: 7508.2427 .. ARI: 0.3939
# Iter: 185 ..  NELBO: 7506.0195 .. ARI: 0.3958
# Iter: 186 ..  NELBO: 7504.8892 .. ARI: 0.3929
# Iter: 187 ..  NELBO: 7502.5459 .. ARI: 0.3935
# Iter: 188 ..  NELBO: 7499.7534 .. ARI: 0.3948
# Iter: 189 ..  NELBO: 7497.5972 .. ARI: 0.4196
# Iter: 190 ..  NELBO: 7495.8423 .. ARI: 0.3962
# Iter: 191 ..  NELBO: 7495.2319 .. ARI: 0.3697
# Iter: 192 ..  NELBO: 7493.1768 .. ARI: 0.3957
# Iter: 193 ..  NELBO: 7491.5723 .. ARI: 0.4201
# Iter: 194 ..  NELBO: 7489.7319 .. ARI: 0.4210
# Iter: 195 ..  NELBO: 7488.2705 .. ARI: 0.3426
# Iter: 196 ..  NELBO: 7487.2622 .. ARI: 0.4224
# Iter: 197 ..  NELBO: 7485.4795 .. ARI: 0.3971
# Iter: 198 ..  NELBO: 7484.7832 .. ARI: 0.4289
# Iter: 199 ..  NELBO: 7482.9731 .. ARI: 0.3846
# Iter: 200 ..  NELBO: 7482.2163 .. ARI: 0.4210
# Iter: 201 ..  NELBO: 7480.7432 .. ARI: 0.4009
# Iter: 202 ..  NELBO: 7478.9995 .. ARI: 0.4031
# Iter: 203 ..  NELBO: 7478.6084 .. ARI: 0.4015
# Iter: 204 ..  NELBO: 7478.4546 .. ARI: 0.4248
# Iter: 205 ..  NELBO: 7477.0176 .. ARI: 0.4015
# Iter: 206 ..  NELBO: 7476.2139 .. ARI: 0.3984
# Iter: 207 ..  NELBO: 7474.6343 .. ARI: 0.4037
# Iter: 208 ..  NELBO: 7472.7051 .. ARI: 0.4197
# Iter: 209 ..  NELBO: 7472.4243 .. ARI: 0.4277
# Iter: 210 ..  NELBO: 7472.0156 .. ARI: 0.4263
# Iter: 211 ..  NELBO: 7470.7695 .. ARI: 0.4282
# Iter: 212 ..  NELBO: 7469.8892 .. ARI: 0.4228
# Iter: 213 ..  NELBO: 7469.2271 .. ARI: 0.4250
# Iter: 214 ..  NELBO: 7466.9644 .. ARI: 0.4256
# Iter: 215 ..  NELBO: 7466.5796 .. ARI: 0.4257
# Iter: 216 ..  NELBO: 7467.3853 .. ARI: 0.4265
# Iter: 217 ..  NELBO: 7465.0181 .. ARI: 0.4214
# Iter: 218 ..  NELBO: 7463.7354 .. ARI: 0.4282
# Iter: 219 ..  NELBO: 7463.1826 .. ARI: 0.4242
# Iter: 220 ..  NELBO: 7462.1318 .. ARI: 0.4268
# Iter: 221 ..  NELBO: 7461.7241 .. ARI: 0.4267
# Iter: 222 ..  NELBO: 7460.1284 .. ARI: 0.4265
# Iter: 223 ..  NELBO: 7460.7573 .. ARI: 0.4267
# Iter: 224 ..  NELBO: 7458.9624 .. ARI: 0.4279
# Iter: 225 ..  NELBO: 7458.1113 .. ARI: 0.4273
# Iter: 226 ..  NELBO: 7458.2319 .. ARI: 0.4284
# Iter: 227 ..  NELBO: 7457.8374 .. ARI: 0.4296
# Iter: 228 ..  NELBO: 7456.9097 .. ARI: 0.4291
# Iter: 229 ..  NELBO: 7455.3296 .. ARI: 0.4285
# Iter: 230 ..  NELBO: 7454.7549 .. ARI: 0.4291
# Iter: 231 ..  NELBO: 7453.8984 .. ARI: 0.4297
# Iter: 232 ..  NELBO: 7453.4399 .. ARI: 0.4286
# Iter: 233 ..  NELBO: 7452.9873 .. ARI: 0.4329
# Iter: 234 ..  NELBO: 7452.1157 .. ARI: 0.4336
# Iter: 235 ..  NELBO: 7452.6533 .. ARI: 0.4344
# Iter: 236 ..  NELBO: 7451.4644 .. ARI: 0.3548
# Iter: 237 ..  NELBO: 7450.8896 .. ARI: 0.4296
# Iter: 238 ..  NELBO: 7450.3208 .. ARI: 0.3588
# Iter: 239 ..  NELBO: 7449.2080 .. ARI: 0.4648
# Iter: 240 ..  NELBO: 7448.9219 .. ARI: 0.3563
# Iter: 241 ..  NELBO: 7447.3218 .. ARI: 0.3563
# Iter: 242 ..  NELBO: 7447.5977 .. ARI: 0.3563
# Iter: 243 ..  NELBO: 7446.2568 .. ARI: 0.3534
# Iter: 244 ..  NELBO: 7446.0977 .. ARI: 0.4904
# Iter: 245 ..  NELBO: 7446.0273 .. ARI: 0.3576
# Iter: 246 ..  NELBO: 7444.6245 .. ARI: 0.4957
# Iter: 247 ..  NELBO: 7443.8589 .. ARI: 0.3582
# Iter: 248 ..  NELBO: 7443.8564 .. ARI: 0.4983
# Iter: 249 ..  NELBO: 7442.6958 .. ARI: 0.5007
# Iter: 250 ..  NELBO: 7441.1138 .. ARI: 0.5021
# Iter: 251 ..  NELBO: 7441.5298 .. ARI: 0.4994
# Iter: 252 ..  NELBO: 7440.9351 .. ARI: 0.5033
# Iter: 253 ..  NELBO: 7439.8076 .. ARI: 0.5070
# Iter: 254 ..  NELBO: 7439.8125 .. ARI: 0.5089
# Iter: 255 ..  NELBO: 7437.9824 .. ARI: 0.5095
# Iter: 256 ..  NELBO: 7438.2261 .. ARI: 0.7386
# Iter: 257 ..  NELBO: 7436.6182 .. ARI: 0.5043
# Iter: 258 ..  NELBO: 7437.0259 .. ARI: 0.5168
# Iter: 259 ..  NELBO: 7434.5820 .. ARI: 0.5140
# Iter: 260 ..  NELBO: 7434.5269 .. ARI: 0.5091
# Iter: 261 ..  NELBO: 7433.8354 .. ARI: 0.5088
# Iter: 262 ..  NELBO: 7434.0454 .. ARI: 0.6165
# Iter: 263 ..  NELBO: 7431.8936 .. ARI: 0.5159
# Iter: 264 ..  NELBO: 7432.6484 .. ARI: 0.5163
# Iter: 265 ..  NELBO: 7431.3022 .. ARI: 0.5194
# Iter: 266 ..  NELBO: 7430.5337 .. ARI: 0.5285
# Iter: 267 ..  NELBO: 7429.6626 .. ARI: 0.5305
# Iter: 268 ..  NELBO: 7428.5659 .. ARI: 0.5280
# Iter: 269 ..  NELBO: 7427.9097 .. ARI: 0.5188
# Iter: 270 ..  NELBO: 7426.6450 .. ARI: 0.5375
# Iter: 271 ..  NELBO: 7426.3174 .. ARI: 0.7700
# Iter: 272 ..  NELBO: 7425.8628 .. ARI: 0.7735
# Iter: 273 ..  NELBO: 7425.0078 .. ARI: 0.7704
# Iter: 274 ..  NELBO: 7424.3799 .. ARI: 0.7749
# Iter: 275 ..  NELBO: 7424.3350 .. ARI: 0.5501
# Iter: 276 ..  NELBO: 7422.8457 .. ARI: 0.7744
# Iter: 277 ..  NELBO: 7421.8774 .. ARI: 0.6453
# Iter: 278 ..  NELBO: 7420.9717 .. ARI: 0.7780
# Iter: 279 ..  NELBO: 7419.9995 .. ARI: 0.7780
# Iter: 280 ..  NELBO: 7420.1230 .. ARI: 0.6922
# Iter: 281 ..  NELBO: 7419.4775 .. ARI: 0.8328
# Iter: 282 ..  NELBO: 7419.1128 .. ARI: 0.8328
# Iter: 283 ..  NELBO: 7417.1431 .. ARI: 0.5430
# Iter: 284 ..  NELBO: 7416.8130 .. ARI: 0.8349
# Iter: 285 ..  NELBO: 7417.0977 .. ARI: 0.7021
# Iter: 286 ..  NELBO: 7415.4331 .. ARI: 0.5334
# Iter: 287 ..  NELBO: 7414.6416 .. ARI: 0.5238
# Iter: 288 ..  NELBO: 7414.3130 .. ARI: 0.6835
# Iter: 289 ..  NELBO: 7413.6245 .. ARI: 0.8424
# Iter: 290 ..  NELBO: 7413.6035 .. ARI: 0.8445
# Iter: 291 ..  NELBO: 7412.7881 .. ARI: 0.8460
# Iter: 292 ..  NELBO: 7412.1680 .. ARI: 0.8449
# Iter: 293 ..  NELBO: 7410.9902 .. ARI: 0.7135
# Iter: 294 ..  NELBO: 7411.0884 .. ARI: 0.5509
# Iter: 295 ..  NELBO: 7409.8032 .. ARI: 0.5439
# Iter: 296 ..  NELBO: 7410.2480 .. ARI: 0.5425
# Iter: 297 ..  NELBO: 7409.4038 .. ARI: 0.7865
# Iter: 298 ..  NELBO: 7409.1113 .. ARI: 0.5568
# Iter: 299 ..  NELBO: 7407.4961 .. ARI: 0.5154
# Iter: 300 ..  NELBO: 7407.2427 .. ARI: 0.4576
# Iter: 301 ..  NELBO: 7407.3682 .. ARI: 0.8506
# Iter: 302 ..  NELBO: 7406.2432 .. ARI: 0.5470
# Iter: 303 ..  NELBO: 7406.1709 .. ARI: 0.5395
# Iter: 304 ..  NELBO: 7405.5156 .. ARI: 0.4585
# Iter: 305 ..  NELBO: 7405.2256 .. ARI: 0.5400
# Iter: 306 ..  NELBO: 7403.6997 .. ARI: 0.5362
# Iter: 307 ..  NELBO: 7404.0576 .. ARI: 0.5449
# Iter: 308 ..  NELBO: 7403.3989 .. ARI: 0.4693
# Iter: 309 ..  NELBO: 7402.8047 .. ARI: 0.4707
# Iter: 310 ..  NELBO: 7402.2017 .. ARI: 0.5891
# Iter: 311 ..  NELBO: 7402.2690 .. ARI: 0.5927
# Iter: 312 ..  NELBO: 7400.8457 .. ARI: 0.4885
# Iter: 313 ..  NELBO: 7401.2305 .. ARI: 0.4692
# Iter: 314 ..  NELBO: 7400.6489 .. ARI: 0.5338
# Iter: 315 ..  NELBO: 7399.2798 .. ARI: 0.4935
# Iter: 316 ..  NELBO: 7399.4106 .. ARI: 0.5605
# Iter: 317 ..  NELBO: 7398.7471 .. ARI: 0.5052
# Iter: 318 ..  NELBO: 7397.8027 .. ARI: 0.7934
# Iter: 319 ..  NELBO: 7397.3799 .. ARI: 0.5536
# Iter: 320 ..  NELBO: 7396.7661 .. ARI: 0.5482
# Iter: 321 ..  NELBO: 7395.8389 .. ARI: 0.4946
# Iter: 322 ..  NELBO: 7394.8223 .. ARI: 0.4930
# Iter: 323 ..  NELBO: 7394.8257 .. ARI: 0.4993
# Iter: 324 ..  NELBO: 7395.1240 .. ARI: 0.5034
# Iter: 325 ..  NELBO: 7393.2607 .. ARI: 0.4982
# Iter: 326 ..  NELBO: 7394.4268 .. ARI: 0.5634
# Iter: 327 ..  NELBO: 7393.0356 .. ARI: 0.5626
# Iter: 328 ..  NELBO: 7392.3096 .. ARI: 0.5552
# Iter: 329 ..  NELBO: 7392.5068 .. ARI: 0.5732
# Iter: 330 ..  NELBO: 7391.8188 .. ARI: 0.5726
# Iter: 331 ..  NELBO: 7390.6436 .. ARI: 0.5715
# Iter: 332 ..  NELBO: 7390.2070 .. ARI: 0.5765
# Iter: 333 ..  NELBO: 7389.4072 .. ARI: 0.8611
# Iter: 334 ..  NELBO: 7389.5830 .. ARI: 0.5736
# Iter: 335 ..  NELBO: 7388.6860 .. ARI: 0.7271
# Iter: 336 ..  NELBO: 7388.2412 .. ARI: 0.7276
# Iter: 337 ..  NELBO: 7388.1685 .. ARI: 0.5033
# Iter: 338 ..  NELBO: 7387.1875 .. ARI: 0.5076
# Iter: 339 ..  NELBO: 7386.0903 .. ARI: 0.4900
# Iter: 340 ..  NELBO: 7386.4575 .. ARI: 0.5260
# Iter: 341 ..  NELBO: 7385.8960 .. ARI: 0.5260
# Iter: 342 ..  NELBO: 7385.3662 .. ARI: 0.4915
# Iter: 343 ..  NELBO: 7386.0156 .. ARI: 0.5127
# Iter: 344 ..  NELBO: 7384.7261 .. ARI: 0.5057
# Iter: 345 ..  NELBO: 7384.4448 .. ARI: 0.8532
# Iter: 346 ..  NELBO: 7384.6665 .. ARI: 0.8564
# Iter: 347 ..  NELBO: 7382.6191 .. ARI: 0.8551
# Iter: 348 ..  NELBO: 7382.3623 .. ARI: 0.5994
# Iter: 349 ..  NELBO: 7382.8203 .. ARI: 0.6224
# Iter: 350 ..  NELBO: 7381.9678 .. ARI: 0.8704
# Iter: 351 ..  NELBO: 7382.3677 .. ARI: 0.8544
# Iter: 352 ..  NELBO: 7381.2329 .. ARI: 0.7894
# Iter: 353 ..  NELBO: 7381.0898 .. ARI: 0.8563
# Iter: 354 ..  NELBO: 7379.5796 .. ARI: 0.7894
# Iter: 355 ..  NELBO: 7379.9199 .. ARI: 0.8696
# Iter: 356 ..  NELBO: 7379.5845 .. ARI: 0.8563
# Iter: 357 ..  NELBO: 7378.9619 .. ARI: 0.8695
# Iter: 358 ..  NELBO: 7377.9146 .. ARI: 0.5757
# Iter: 359 ..  NELBO: 7377.8511 .. ARI: 0.5928
# Iter: 360 ..  NELBO: 7376.8140 .. ARI: 0.5761
# Iter: 361 ..  NELBO: 7377.1802 .. ARI: 0.6154
# Iter: 362 ..  NELBO: 7377.1128 .. ARI: 0.5962
# Iter: 363 ..  NELBO: 7376.9736 .. ARI: 0.5924
# Iter: 364 ..  NELBO: 7375.3579 .. ARI: 0.8594
# Iter: 365 ..  NELBO: 7375.2002 .. ARI: 0.8729
# Iter: 366 ..  NELBO: 7375.6196 .. ARI: 0.5766
# Iter: 367 ..  NELBO: 7374.1733 .. ARI: 0.8749
# Iter: 368 ..  NELBO: 7374.4434 .. ARI: 0.8721
# Iter: 369 ..  NELBO: 7372.6543 .. ARI: 0.7235
# Iter: 370 ..  NELBO: 7373.1865 .. ARI: 0.7262
# Iter: 371 ..  NELBO: 7373.3184 .. ARI: 0.6206
# Iter: 372 ..  NELBO: 7372.1919 .. ARI: 0.8764
# Iter: 373 ..  NELBO: 7373.7295 .. ARI: 0.5743
# Iter: 374 ..  NELBO: 7371.9023 .. ARI: 0.5933
# Iter: 375 ..  NELBO: 7370.7769 .. ARI: 0.5621
# Iter: 376 ..  NELBO: 7370.2896 .. ARI: 0.8559
# Iter: 377 ..  NELBO: 7370.6499 .. ARI: 0.6042
# Iter: 378 ..  NELBO: 7369.0596 .. ARI: 0.8574
# Iter: 379 ..  NELBO: 7369.4189 .. ARI: 0.5935
# Iter: 380 ..  NELBO: 7368.3994 .. ARI: 0.5953
# Iter: 381 ..  NELBO: 7367.6064 .. ARI: 0.5937
# Iter: 382 ..  NELBO: 7366.9502 .. ARI: 0.8565
# Iter: 383 ..  NELBO: 7365.3564 .. ARI: 0.5918
# Iter: 384 ..  NELBO: 7365.0376 .. ARI: 0.5590
# Iter: 385 ..  NELBO: 7365.3652 .. ARI: 0.5638
# Iter: 386 ..  NELBO: 7364.2505 .. ARI: 0.5916
# Iter: 387 ..  NELBO: 7364.1733 .. ARI: 0.5917
# Iter: 388 ..  NELBO: 7363.3296 .. ARI: 0.6137
# Iter: 389 ..  NELBO: 7362.3101 .. ARI: 0.6098
# Iter: 390 ..  NELBO: 7361.7383 .. ARI: 0.5997
# Iter: 391 ..  NELBO: 7361.1069 .. ARI: 0.5992
# Iter: 392 ..  NELBO: 7359.7251 .. ARI: 0.5996
# Iter: 393 ..  NELBO: 7359.3706 .. ARI: 0.5915
# Iter: 394 ..  NELBO: 7359.1973 .. ARI: 0.6171
# Iter: 395 ..  NELBO: 7359.3647 .. ARI: 0.5688
# Iter: 396 ..  NELBO: 7358.4204 .. ARI: 0.5920
# Iter: 397 ..  NELBO: 7358.9248 .. ARI: 0.5897
# Iter: 398 ..  NELBO: 7356.5879 .. ARI: 0.6012
# Iter: 399 ..  NELBO: 7356.8213 .. ARI: 0.5892
# Iter: 400 ..  NELBO: 7356.2661 .. ARI: 0.5882
# Iter: 401 ..  NELBO: 7355.6499 .. ARI: 0.5923
# Iter: 402 ..  NELBO: 7355.6577 .. ARI: 0.5935
# Iter: 403 ..  NELBO: 7355.2563 .. ARI: 0.6081
# Iter: 404 ..  NELBO: 7353.1377 .. ARI: 0.5890
# Iter: 405 ..  NELBO: 7353.0635 .. ARI: 0.5944
# Iter: 406 ..  NELBO: 7353.6714 .. ARI: 0.5937
# Iter: 407 ..  NELBO: 7352.5127 .. ARI: 0.5937
# Iter: 408 ..  NELBO: 7351.7354 .. ARI: 0.5937
# Iter: 409 ..  NELBO: 7351.4116 .. ARI: 0.5911
# Iter: 410 ..  NELBO: 7351.3066 .. ARI: 0.5911
# Iter: 411 ..  NELBO: 7351.3813 .. ARI: 0.5866
# Iter: 412 ..  NELBO: 7349.8813 .. ARI: 0.5863
# Iter: 413 ..  NELBO: 7349.5259 .. ARI: 0.6093
# Iter: 414 ..  NELBO: 7350.0830 .. ARI: 0.5940
# Iter: 415 ..  NELBO: 7348.0840 .. ARI: 0.5942
# Iter: 416 ..  NELBO: 7348.3940 .. ARI: 0.5860
# Iter: 417 ..  NELBO: 7347.6772 .. ARI: 0.5938
# Iter: 418 ..  NELBO: 7347.4204 .. ARI: 0.5876
# Iter: 419 ..  NELBO: 7345.9233 .. ARI: 0.5924
# Iter: 420 ..  NELBO: 7345.2090 .. ARI: 0.5937
# Iter: 421 ..  NELBO: 7346.0864 .. ARI: 0.5889
# Iter: 422 ..  NELBO: 7344.3242 .. ARI: 0.5828
# Iter: 423 ..  NELBO: 7343.0161 .. ARI: 0.5925
# Iter: 424 ..  NELBO: 7344.4238 .. ARI: 0.5920
# Iter: 425 ..  NELBO: 7342.8413 .. ARI: 0.5933
# Iter: 426 ..  NELBO: 7342.1787 .. ARI: 0.5872
# Iter: 427 ..  NELBO: 7342.3281 .. ARI: 0.5913
# Iter: 428 ..  NELBO: 7340.3179 .. ARI: 0.5843
# Iter: 429 ..  NELBO: 7339.8901 .. ARI: 0.5838
# Iter: 430 ..  NELBO: 7340.1084 .. ARI: 0.5919
# Iter: 431 ..  NELBO: 7338.4155 .. ARI: 0.5835
# Iter: 432 ..  NELBO: 7337.1094 .. ARI: 0.5919
# Iter: 433 ..  NELBO: 7337.1724 .. ARI: 0.5835
# Iter: 434 ..  NELBO: 7336.6152 .. ARI: 0.5810
# Iter: 435 ..  NELBO: 7335.9858 .. ARI: 0.5841
# Iter: 436 ..  NELBO: 7334.4204 .. ARI: 0.5791
# Iter: 437 ..  NELBO: 7335.4399 .. ARI: 0.5770
# Iter: 438 ..  NELBO: 7333.9648 .. ARI: 0.5783
# Iter: 439 ..  NELBO: 7334.2773 .. ARI: 0.5778
# Iter: 440 ..  NELBO: 7332.8066 .. ARI: 0.5783
# Iter: 441 ..  NELBO: 7333.5767 .. ARI: 0.5774
# Iter: 442 ..  NELBO: 7331.7480 .. ARI: 0.5778
# Iter: 443 ..  NELBO: 7331.5342 .. ARI: 0.5766
# Iter: 444 ..  NELBO: 7329.9961 .. ARI: 0.5785
# Iter: 445 ..  NELBO: 7330.0620 .. ARI: 0.5778
# Iter: 446 ..  NELBO: 7329.0786 .. ARI: 0.5790
# Iter: 447 ..  NELBO: 7329.0986 .. ARI: 0.5779
# Iter: 448 ..  NELBO: 7328.1357 .. ARI: 0.5778
# Iter: 449 ..  NELBO: 7327.2915 .. ARI: 0.5795
# Iter: 450 ..  NELBO: 7326.0962 .. ARI: 0.5778
# Iter: 451 ..  NELBO: 7326.5142 .. ARI: 0.5824
# Iter: 452 ..  NELBO: 7326.1309 .. ARI: 0.5822
# Iter: 453 ..  NELBO: 7324.1670 .. ARI: 0.5787
# Iter: 454 ..  NELBO: 7324.6138 .. ARI: 0.5783
# Iter: 455 ..  NELBO: 7325.5645 .. ARI: 0.5787
# Iter: 456 ..  NELBO: 7323.5322 .. ARI: 0.5791
# Iter: 457 ..  NELBO: 7322.8770 .. ARI: 0.5773
# Iter: 458 ..  NELBO: 7322.2622 .. ARI: 0.5816
# Iter: 459 ..  NELBO: 7321.1143 .. ARI: 0.5830
# Iter: 460 ..  NELBO: 7321.7656 .. ARI: 0.5816
# Iter: 461 ..  NELBO: 7320.9375 .. ARI: 0.5799
# Iter: 462 ..  NELBO: 7320.5547 .. ARI: 0.5800
# Iter: 463 ..  NELBO: 7319.0298 .. ARI: 0.5808
# Iter: 464 ..  NELBO: 7318.9800 .. ARI: 0.5808
# Iter: 465 ..  NELBO: 7317.9038 .. ARI: 0.5812
# Iter: 466 ..  NELBO: 7317.7754 .. ARI: 0.5826
# Iter: 467 ..  NELBO: 7318.9575 .. ARI: 0.5822
# Iter: 468 ..  NELBO: 7317.0781 .. ARI: 0.5835
# Iter: 469 ..  NELBO: 7316.0337 .. ARI: 0.5813
# Iter: 470 ..  NELBO: 7316.4756 .. ARI: 0.5814
# Iter: 471 ..  NELBO: 7315.2236 .. ARI: 0.5827
# Iter: 472 ..  NELBO: 7315.5361 .. ARI: 0.5821
# Iter: 473 ..  NELBO: 7313.9302 .. ARI: 0.5833
# Iter: 474 ..  NELBO: 7314.6968 .. ARI: 0.5833
# Iter: 475 ..  NELBO: 7313.3145 .. ARI: 0.5821
# Iter: 476 ..  NELBO: 7313.5142 .. ARI: 0.5822
# Iter: 477 ..  NELBO: 7313.7988 .. ARI: 0.5814
# Iter: 478 ..  NELBO: 7313.4727 .. ARI: 0.5809
# Iter: 479 ..  NELBO: 7312.9404 .. ARI: 0.5822
# Iter: 480 ..  NELBO: 7312.4287 .. ARI: 0.5838
# Iter: 481 ..  NELBO: 7312.4741 .. ARI: 0.5843
# Iter: 482 ..  NELBO: 7310.8838 .. ARI: 0.5865
# Iter: 483 ..  NELBO: 7310.5000 .. ARI: 0.5838
# Iter: 484 ..  NELBO: 7310.0332 .. ARI: 0.5838
# Iter: 485 ..  NELBO: 7310.2866 .. ARI: 0.5849
# Iter: 486 ..  NELBO: 7309.8003 .. ARI: 0.5833
# Iter: 487 ..  NELBO: 7309.6758 .. ARI: 0.5850
# Iter: 488 ..  NELBO: 7308.4307 .. ARI: 0.5840
# Iter: 489 ..  NELBO: 7308.3901 .. ARI: 0.5837
# Iter: 490 ..  NELBO: 7307.7153 .. ARI: 0.5849
# Iter: 491 ..  NELBO: 7307.8193 .. ARI: 0.5861
# Iter: 492 ..  NELBO: 7307.0278 .. ARI: 0.5833
# Iter: 493 ..  NELBO: 7306.5684 .. ARI: 0.5819
# Iter: 494 ..  NELBO: 7305.1670 .. ARI: 0.5837
# Iter: 495 ..  NELBO: 7305.7148 .. ARI: 0.5846
# Iter: 496 ..  NELBO: 7305.6187 .. ARI: 0.5856
# Iter: 497 ..  NELBO: 7304.8120 .. ARI: 0.5856
# Iter: 498 ..  NELBO: 7304.0483 .. ARI: 0.5844
# Iter: 499 ..  NELBO: 7303.8750 .. ARI: 0.5837
# Iter: 500 ..  NELBO: 7303.6118 .. ARI: 0.5843
# Iter: 501 ..  NELBO: 7303.8701 .. ARI: 0.5843
# Iter: 502 ..  NELBO: 7303.3359 .. ARI: 0.5838
# Iter: 503 ..  NELBO: 7302.5649 .. ARI: 0.5837
# Iter: 504 ..  NELBO: 7302.2466 .. ARI: 0.5830
# Iter: 505 ..  NELBO: 7301.9365 .. ARI: 0.5825
# Iter: 506 ..  NELBO: 7300.8779 .. ARI: 0.5832
# Iter: 507 ..  NELBO: 7300.8643 .. ARI: 0.5834
# Iter: 508 ..  NELBO: 7301.5488 .. ARI: 0.5834
# Iter: 509 ..  NELBO: 7299.8198 .. ARI: 0.5841
# Iter: 510 ..  NELBO: 7300.4502 .. ARI: 0.5841
# Iter: 511 ..  NELBO: 7299.7710 .. ARI: 0.5841
# Iter: 512 ..  NELBO: 7300.2876 .. ARI: 0.5841
# Iter: 513 ..  NELBO: 7299.5142 .. ARI: 0.5847
# Iter: 514 ..  NELBO: 7300.0317 .. ARI: 0.5843
# Iter: 515 ..  NELBO: 7298.6885 .. ARI: 0.5849
# Iter: 516 ..  NELBO: 7298.9897 .. ARI: 0.5840
# Iter: 517 ..  NELBO: 7298.5190 .. ARI: 0.5836
# Iter: 518 ..  NELBO: 7298.0869 .. ARI: 0.5840
# Iter: 519 ..  NELBO: 7297.6748 .. ARI: 0.5850
# Iter: 520 ..  NELBO: 7297.2939 .. ARI: 0.5846
# Iter: 521 ..  NELBO: 7297.9644 .. ARI: 0.5847
# Iter: 522 ..  NELBO: 7297.6123 .. ARI: 0.5829
# Iter: 523 ..  NELBO: 7297.1118 .. ARI: 0.6192
# Iter: 524 ..  NELBO: 7296.7764 .. ARI: 0.5838
# Iter: 525 ..  NELBO: 7295.9551 .. ARI: 0.5838
# Iter: 526 ..  NELBO: 7296.9634 .. ARI: 0.5831
# Iter: 527 ..  NELBO: 7296.4780 .. ARI: 0.5835
# Iter: 528 ..  NELBO: 7296.5342 .. ARI: 0.5813
# Iter: 529 ..  NELBO: 7295.1953 .. ARI: 0.5809
# Iter: 530 ..  NELBO: 7295.6255 .. ARI: 0.5817
# Iter: 531 ..  NELBO: 7294.4214 .. ARI: 0.5827
# Iter: 532 ..  NELBO: 7294.6816 .. ARI: 0.5819
# Iter: 533 ..  NELBO: 7293.4502 .. ARI: 0.5819
# Iter: 534 ..  NELBO: 7294.5508 .. ARI: 0.5819
# Iter: 535 ..  NELBO: 7293.7251 .. ARI: 0.5819
# Iter: 536 ..  NELBO: 7293.5405 .. ARI: 0.5819
# Iter: 537 ..  NELBO: 7293.9258 .. ARI: 0.5819
# Iter: 538 ..  NELBO: 7292.3779 .. ARI: 0.5819
# Iter: 539 ..  NELBO: 7293.0298 .. ARI: 0.5813
# Iter: 540 ..  NELBO: 7291.7974 .. ARI: 0.5817
# Iter: 541 ..  NELBO: 7291.6973 .. ARI: 0.5800
# Iter: 542 ..  NELBO: 7292.4263 .. ARI: 0.5810
# Iter: 543 ..  NELBO: 7291.6978 .. ARI: 0.5818
# Iter: 544 ..  NELBO: 7290.7710 .. ARI: 0.5810
# Iter: 545 ..  NELBO: 7291.2046 .. ARI: 0.5820
# Iter: 546 ..  NELBO: 7291.3462 .. ARI: 0.5814
# Iter: 547 ..  NELBO: 7290.4702 .. ARI: 0.5843
# Iter: 548 ..  NELBO: 7290.9614 .. ARI: 0.5831
# Iter: 549 ..  NELBO: 7289.7300 .. ARI: 0.5827
# Iter: 550 ..  NELBO: 7289.9375 .. ARI: 0.6187
# Iter: 551 ..  NELBO: 7289.2646 .. ARI: 0.6201
# Iter: 552 ..  NELBO: 7289.1460 .. ARI: 0.6201
# Iter: 553 ..  NELBO: 7289.5010 .. ARI: 0.6194
# Iter: 554 ..  NELBO: 7288.9243 .. ARI: 0.6194
# Iter: 555 ..  NELBO: 7288.9023 .. ARI: 0.6185
# Iter: 556 ..  NELBO: 7288.7783 .. ARI: 0.6194
# Iter: 557 ..  NELBO: 7288.4741 .. ARI: 0.6194
# Iter: 558 ..  NELBO: 7287.3813 .. ARI: 0.5826
# Iter: 559 ..  NELBO: 7287.9043 .. ARI: 0.6194
# Iter: 560 ..  NELBO: 7286.9570 .. ARI: 0.6194
# Iter: 561 ..  NELBO: 7286.4131 .. ARI: 0.6194
# Iter: 562 ..  NELBO: 7285.8193 .. ARI: 0.5830
# Iter: 563 ..  NELBO: 7286.8130 .. ARI: 0.6198
# Iter: 564 ..  NELBO: 7286.2925 .. ARI: 0.5830
# Iter: 565 ..  NELBO: 7285.5293 .. ARI: 0.6201
# Iter: 566 ..  NELBO: 7284.5972 .. ARI: 0.6174
# Iter: 567 ..  NELBO: 7285.9761 .. ARI: 0.6174
# Iter: 568 ..  NELBO: 7285.3540 .. ARI: 0.5830
# Iter: 569 ..  NELBO: 7283.9038 .. ARI: 0.5830
# Iter: 570 ..  NELBO: 7283.7876 .. ARI: 0.6172
# Iter: 571 ..  NELBO: 7284.5015 .. ARI: 0.5830
# Iter: 572 ..  NELBO: 7283.2207 .. ARI: 0.6172
# Iter: 573 ..  NELBO: 7283.5547 .. ARI: 0.6166
# Iter: 574 ..  NELBO: 7282.8467 .. ARI: 0.6166
# Iter: 575 ..  NELBO: 7282.9409 .. ARI: 0.5818
# Iter: 576 ..  NELBO: 7282.5498 .. ARI: 0.5818
# Iter: 577 ..  NELBO: 7282.1465 .. ARI: 0.5830
# Iter: 578 ..  NELBO: 7282.2178 .. ARI: 0.5830
# Iter: 579 ..  NELBO: 7281.8604 .. ARI: 0.5838
# Iter: 580 ..  NELBO: 7280.4199 .. ARI: 0.5838
# Iter: 581 ..  NELBO: 7281.3428 .. ARI: 0.5834
# Iter: 582 ..  NELBO: 7281.3438 .. ARI: 0.5839
# Iter: 583 ..  NELBO: 7281.0068 .. ARI: 0.5834
# Iter: 584 ..  NELBO: 7280.6641 .. ARI: 0.5838
# Iter: 585 ..  NELBO: 7280.7129 .. ARI: 0.5845
# Iter: 586 ..  NELBO: 7280.8677 .. ARI: 0.5853
# Iter: 587 ..  NELBO: 7280.1396 .. ARI: 0.5845
# Iter: 588 ..  NELBO: 7279.9688 .. ARI: 0.5838
# Iter: 589 ..  NELBO: 7280.4414 .. ARI: 0.5821
# Iter: 590 ..  NELBO: 7279.5112 .. ARI: 0.5821
# Iter: 591 ..  NELBO: 7279.0957 .. ARI: 0.5834
# Iter: 592 ..  NELBO: 7278.4985 .. ARI: 0.5838
# Iter: 593 ..  NELBO: 7278.8955 .. ARI: 0.6185
# Iter: 594 ..  NELBO: 7278.9116 .. ARI: 0.6194
# Iter: 595 ..  NELBO: 7278.0703 .. ARI: 0.5825
# Iter: 596 ..  NELBO: 7278.0415 .. ARI: 0.5829
# Iter: 597 ..  NELBO: 7279.0713 .. ARI: 0.5829
# Iter: 598 ..  NELBO: 7277.9355 .. ARI: 0.5829
# Iter: 599 ..  NELBO: 7277.8306 .. ARI: 0.5825
# Iter: 600 ..  NELBO: 7277.9961 .. ARI: 0.5817
# Iter: 601 ..  NELBO: 7278.1606 .. ARI: 0.6018
# Iter: 602 ..  NELBO: 7277.5273 .. ARI: 0.6376
# Iter: 603 ..  NELBO: 7277.7642 .. ARI: 0.6018
# Iter: 604 ..  NELBO: 7277.3291 .. ARI: 0.6382
# Iter: 605 ..  NELBO: 7277.1680 .. ARI: 0.6382
# Iter: 606 ..  NELBO: 7276.9204 .. ARI: 0.6018
# Iter: 607 ..  NELBO: 7277.1694 .. ARI: 0.6025
# Iter: 608 ..  NELBO: 7276.5029 .. ARI: 0.6382
# Iter: 609 ..  NELBO: 7275.9609 .. ARI: 0.6025
# Iter: 610 ..  NELBO: 7275.5679 .. ARI: 0.6025
# Iter: 611 ..  NELBO: 7275.2925 .. ARI: 0.6028
# Iter: 612 ..  NELBO: 7275.5273 .. ARI: 0.6014
# Iter: 613 ..  NELBO: 7275.7915 .. ARI: 0.6391
# Iter: 614 ..  NELBO: 7275.4233 .. ARI: 0.6014
# Iter: 615 ..  NELBO: 7274.5757 .. ARI: 0.5818
# Iter: 616 ..  NELBO: 7275.2241 .. ARI: 0.5814
# Iter: 617 ..  NELBO: 7274.6812 .. ARI: 0.5814
# Iter: 618 ..  NELBO: 7274.2915 .. ARI: 0.5814
# Iter: 619 ..  NELBO: 7275.0063 .. ARI: 0.6378
# Iter: 620 ..  NELBO: 7274.5991 .. ARI: 0.6378
# Iter: 621 ..  NELBO: 7274.0312 .. ARI: 0.6018
# Iter: 622 ..  NELBO: 7273.6665 .. ARI: 0.6018
# Iter: 623 ..  NELBO: 7273.5986 .. ARI: 0.6387
# Iter: 624 ..  NELBO: 7273.9448 .. ARI: 0.5821
# Iter: 625 ..  NELBO: 7273.9072 .. ARI: 0.6191
# Iter: 626 ..  NELBO: 7273.0200 .. ARI: 0.6387
# Iter: 627 ..  NELBO: 7273.5825 .. ARI: 0.6387
# Iter: 628 ..  NELBO: 7272.2979 .. ARI: 0.6381
# Iter: 629 ..  NELBO: 7273.1460 .. ARI: 0.6171
# Iter: 630 ..  NELBO: 7272.5596 .. ARI: 0.6037
# Iter: 631 ..  NELBO: 7272.0063 .. ARI: 0.6035
# Iter: 632 ..  NELBO: 7271.7480 .. ARI: 0.6010
# Iter: 633 ..  NELBO: 7273.1118 .. ARI: 0.6398
# Iter: 634 ..  NELBO: 7272.6094 .. ARI: 0.6254
# Iter: 635 ..  NELBO: 7272.3721 .. ARI: 0.6254
# Iter: 636 ..  NELBO: 7271.8901 .. ARI: 0.6380
# Iter: 637 ..  NELBO: 7272.6060 .. ARI: 0.6376
# Iter: 638 ..  NELBO: 7271.2354 .. ARI: 0.6245
# Iter: 639 ..  NELBO: 7271.8896 .. ARI: 0.6238
# Iter: 640 ..  NELBO: 7271.4575 .. ARI: 0.6234
# Iter: 641 ..  NELBO: 7270.1938 .. ARI: 0.6234
# Iter: 642 ..  NELBO: 7270.2192 .. ARI: 0.6234
# Iter: 643 ..  NELBO: 7269.8315 .. ARI: 0.6234
# Iter: 644 ..  NELBO: 7270.7007 .. ARI: 0.6225
# Iter: 645 ..  NELBO: 7270.1533 .. ARI: 0.6233
# Iter: 646 ..  NELBO: 7269.8662 .. ARI: 0.6234
# Iter: 647 ..  NELBO: 7269.3442 .. ARI: 0.6234
# Iter: 648 ..  NELBO: 7269.2119 .. ARI: 0.5898
# Iter: 649 ..  NELBO: 7268.5132 .. ARI: 0.6054
# Iter: 650 ..  NELBO: 7269.1392 .. ARI: 0.6045
# Iter: 651 ..  NELBO: 7268.7012 .. ARI: 0.6057
# Iter: 652 ..  NELBO: 7268.9580 .. ARI: 0.6064
# Iter: 653 ..  NELBO: 7269.6699 .. ARI: 0.6056
# Iter: 654 ..  NELBO: 7268.3931 .. ARI: 0.6010
# Iter: 655 ..  NELBO: 7267.5894 .. ARI: 0.6043
# Iter: 656 ..  NELBO: 7268.4785 .. ARI: 0.6043
# Iter: 657 ..  NELBO: 7267.8813 .. ARI: 0.6057
# Iter: 658 ..  NELBO: 7268.2109 .. ARI: 0.6064
# Iter: 659 ..  NELBO: 7267.6948 .. ARI: 0.6389
# Iter: 660 ..  NELBO: 7267.6143 .. ARI: 0.6052
# Iter: 661 ..  NELBO: 7268.2705 .. ARI: 0.6388
# Iter: 662 ..  NELBO: 7267.9717 .. ARI: 0.6064
# Iter: 663 ..  NELBO: 7267.1421 .. ARI: 0.6057
# Iter: 664 ..  NELBO: 7266.7847 .. ARI: 0.6082
# Iter: 665 ..  NELBO: 7266.9058 .. ARI: 0.6082
# Iter: 666 ..  NELBO: 7266.5215 .. ARI: 0.6082
# Iter: 667 ..  NELBO: 7266.5020 .. ARI: 0.6074
# Iter: 668 ..  NELBO: 7266.9878 .. ARI: 0.6079
# Iter: 669 ..  NELBO: 7266.5234 .. ARI: 0.6082
# Iter: 670 ..  NELBO: 7265.7539 .. ARI: 0.6408
# Iter: 671 ..  NELBO: 7265.9292 .. ARI: 0.6049
# Iter: 672 ..  NELBO: 7266.2007 .. ARI: 0.6414
# Iter: 673 ..  NELBO: 7266.4785 .. ARI: 0.6408
# Iter: 674 ..  NELBO: 7266.1538 .. ARI: 0.6082
# Iter: 675 ..  NELBO: 7265.0483 .. ARI: 0.6082
# Iter: 676 ..  NELBO: 7265.5483 .. ARI: 0.6079
# Iter: 677 ..  NELBO: 7265.3145 .. ARI: 0.6082
# Iter: 678 ..  NELBO: 7265.6978 .. ARI: 0.6083
# Iter: 679 ..  NELBO: 7264.8008 .. ARI: 0.6082
# Iter: 680 ..  NELBO: 7266.0581 .. ARI: 0.6074
# Iter: 681 ..  NELBO: 7265.0454 .. ARI: 0.6074
# Iter: 682 ..  NELBO: 7265.5073 .. ARI: 0.6082
# Iter: 683 ..  NELBO: 7264.6045 .. ARI: 0.6070
# Iter: 684 ..  NELBO: 7266.0747 .. ARI: 0.6082
# Iter: 685 ..  NELBO: 7264.6538 .. ARI: 0.6082
# Iter: 686 ..  NELBO: 7264.7334 .. ARI: 0.6082
# Iter: 687 ..  NELBO: 7263.7905 .. ARI: 0.6082
# Iter: 688 ..  NELBO: 7263.5952 .. ARI: 0.6074
# Iter: 689 ..  NELBO: 7264.0415 .. ARI: 0.6080
# Iter: 690 ..  NELBO: 7264.4937 .. ARI: 0.6079
# Iter: 691 ..  NELBO: 7264.9907 .. ARI: 0.6070
# Iter: 692 ..  NELBO: 7263.9951 .. ARI: 0.6074
# Iter: 693 ..  NELBO: 7264.8101 .. ARI: 0.6074
# Iter: 694 ..  NELBO: 7263.2100 .. ARI: 0.6082
# Iter: 695 ..  NELBO: 7264.0303 .. ARI: 0.6067
# Iter: 696 ..  NELBO: 7264.2495 .. ARI: 0.6067
# Iter: 697 ..  NELBO: 7265.0723 .. ARI: 0.6042
# Iter: 698 ..  NELBO: 7262.9795 .. ARI: 0.6042
# Iter: 699 ..  NELBO: 7264.2588 .. ARI: 0.6079
# Iter: 700 ..  NELBO: 7263.3745 .. ARI: 0.6083
# Iter: 701 ..  NELBO: 7263.1519 .. ARI: 0.6074
# Iter: 702 ..  NELBO: 7262.1758 .. ARI: 0.6079
# Iter: 703 ..  NELBO: 7262.5811 .. ARI: 0.6009
# Iter: 704 ..  NELBO: 7262.3867 .. ARI: 0.6079
# Iter: 705 ..  NELBO: 7262.3354 .. ARI: 0.6042
# Iter: 706 ..  NELBO: 7262.7764 .. ARI: 0.6045
# Iter: 707 ..  NELBO: 7262.1143 .. ARI: 0.6008
# Iter: 708 ..  NELBO: 7262.2349 .. ARI: 0.6013
# Iter: 709 ..  NELBO: 7261.8872 .. ARI: 0.6013
# Iter: 710 ..  NELBO: 7261.5942 .. ARI: 0.6067
# Iter: 711 ..  NELBO: 7262.0605 .. ARI: 0.5870
# Iter: 712 ..  NELBO: 7261.6460 .. ARI: 0.5896
# Iter: 713 ..  NELBO: 7262.0322 .. ARI: 0.5899
# Iter: 714 ..  NELBO: 7262.0972 .. ARI: 0.5899
# Iter: 715 ..  NELBO: 7261.4302 .. ARI: 0.5933
# Iter: 716 ..  NELBO: 7262.0083 .. ARI: 0.5933
# Iter: 717 ..  NELBO: 7260.6543 .. ARI: 0.5920
# Iter: 718 ..  NELBO: 7260.7998 .. ARI: 0.5936
# Iter: 719 ..  NELBO: 7260.7661 .. ARI: 0.5923
# Iter: 720 ..  NELBO: 7260.5801 .. ARI: 0.5911
# Iter: 721 ..  NELBO: 7261.4263 .. ARI: 0.5923
# Iter: 722 ..  NELBO: 7260.8647 .. ARI: 0.5936
# Iter: 723 ..  NELBO: 7260.3359 .. ARI: 0.5936
# Iter: 724 ..  NELBO: 7260.4453 .. ARI: 0.5858
# Iter: 725 ..  NELBO: 7259.7754 .. ARI: 0.5850
# Iter: 726 ..  NELBO: 7260.9346 .. ARI: 0.5903
# Iter: 727 ..  NELBO: 7261.2031 .. ARI: 0.5900
# Iter: 728 ..  NELBO: 7260.8867 .. ARI: 0.5920
# Iter: 729 ..  NELBO: 7259.9771 .. ARI: 0.5923
# Iter: 730 ..  NELBO: 7260.0767 .. ARI: 0.5916
# Iter: 731 ..  NELBO: 7260.0928 .. ARI: 0.5908
# Iter: 732 ..  NELBO: 7259.4736 .. ARI: 0.5907
# Iter: 733 ..  NELBO: 7260.1689 .. ARI: 0.5948
# Iter: 734 ..  NELBO: 7259.9829 .. ARI: 0.5869
# Iter: 735 ..  NELBO: 7259.3208 .. ARI: 0.5882
# Iter: 736 ..  NELBO: 7259.6045 .. ARI: 0.5881
# Iter: 737 ..  NELBO: 7258.9746 .. ARI: 0.5898
# Iter: 738 ..  NELBO: 7259.6118 .. ARI: 0.5915
# Iter: 739 ..  NELBO: 7259.5898 .. ARI: 0.5916
# Iter: 740 ..  NELBO: 7259.1719 .. ARI: 0.5915
# Iter: 741 ..  NELBO: 7260.5469 .. ARI: 0.5923
# Iter: 742 ..  NELBO: 7259.1323 .. ARI: 0.5923
# Iter: 743 ..  NELBO: 7259.0732 .. ARI: 0.5923
# Iter: 744 ..  NELBO: 7259.1943 .. ARI: 0.5870
# Iter: 745 ..  NELBO: 7258.9033 .. ARI: 0.6014
# Iter: 746 ..  NELBO: 7258.9160 .. ARI: 0.5903
# Iter: 747 ..  NELBO: 7257.9893 .. ARI: 0.5935
# Iter: 748 ..  NELBO: 7259.2280 .. ARI: 0.5940
# Iter: 749 ..  NELBO: 7257.6787 .. ARI: 0.5932
# Iter: 750 ..  NELBO: 7259.2954 .. ARI: 0.5912
# Iter: 751 ..  NELBO: 7259.1313 .. ARI: 0.5911
# Iter: 752 ..  NELBO: 7258.3657 .. ARI: 0.5918
# Iter: 753 ..  NELBO: 7258.4434 .. ARI: 0.5911
# Iter: 754 ..  NELBO: 7258.4541 .. ARI: 0.5899
# Iter: 755 ..  NELBO: 7258.1187 .. ARI: 0.5936
# Iter: 756 ..  NELBO: 7258.5454 .. ARI: 0.5860
# Iter: 757 ..  NELBO: 7257.3335 .. ARI: 0.5867
# Iter: 758 ..  NELBO: 7258.1948 .. ARI: 0.5924
# Iter: 759 ..  NELBO: 7257.9351 .. ARI: 0.5912
# Iter: 760 ..  NELBO: 7257.5562 .. ARI: 0.6057
# Iter: 761 ..  NELBO: 7259.0220 .. ARI: 0.6057
# Iter: 762 ..  NELBO: 7258.0298 .. ARI: 0.6044
# Iter: 763 ..  NELBO: 7257.0469 .. ARI: 0.5899
# Iter: 764 ..  NELBO: 7257.6465 .. ARI: 0.5936
# Iter: 765 ..  NELBO: 7257.8276 .. ARI: 0.5911
# Iter: 766 ..  NELBO: 7258.4062 .. ARI: 0.5911
# Iter: 767 ..  NELBO: 7257.8867 .. ARI: 0.6065
# Iter: 768 ..  NELBO: 7257.8281 .. ARI: 0.6082
# Iter: 769 ..  NELBO: 7257.2051 .. ARI: 0.6085
# Iter: 770 ..  NELBO: 7257.0254 .. ARI: 0.6060
# Iter: 771 ..  NELBO: 7257.1499 .. ARI: 0.6039
# Iter: 772 ..  NELBO: 7256.0469 .. ARI: 0.6044
# Iter: 773 ..  NELBO: 7256.8296 .. ARI: 0.6016
# Iter: 774 ..  NELBO: 7257.1548 .. ARI: 0.6040
# Iter: 775 ..  NELBO: 7257.5884 .. ARI: 0.6049
# Iter: 776 ..  NELBO: 7256.9175 .. ARI: 0.6099
# Iter: 777 ..  NELBO: 7256.4131 .. ARI: 0.6068
# Iter: 778 ..  NELBO: 7256.5020 .. ARI: 0.6060
# Iter: 779 ..  NELBO: 7256.3394 .. ARI: 0.6073
# Iter: 780 ..  NELBO: 7255.8936 .. ARI: 0.6073
# Iter: 781 ..  NELBO: 7255.7227 .. ARI: 0.5900
# Iter: 782 ..  NELBO: 7256.8013 .. ARI: 0.5944
# Iter: 783 ..  NELBO: 7255.4863 .. ARI: 0.5944
# Iter: 784 ..  NELBO: 7255.6851 .. ARI: 0.5944
# Iter: 785 ..  NELBO: 7256.3833 .. ARI: 0.5944
# Iter: 786 ..  NELBO: 7255.8042 .. ARI: 0.5944
# Iter: 787 ..  NELBO: 7255.6675 .. ARI: 0.5936
# Iter: 788 ..  NELBO: 7256.0952 .. ARI: 0.5936
# Iter: 789 ..  NELBO: 7255.6279 .. ARI: 0.5911
# Iter: 790 ..  NELBO: 7255.1431 .. ARI: 0.5919
# Iter: 791 ..  NELBO: 7255.0767 .. ARI: 0.5944
# Iter: 792 ..  NELBO: 7254.3696 .. ARI: 0.5944
# Iter: 793 ..  NELBO: 7254.7622 .. ARI: 0.5919
# Iter: 794 ..  NELBO: 7255.6416 .. ARI: 0.5911
# Iter: 795 ..  NELBO: 7255.4575 .. ARI: 0.5936
# Iter: 796 ..  NELBO: 7254.8179 .. ARI: 0.5911
# Iter: 797 ..  NELBO: 7254.6528 .. ARI: 0.5911
# Iter: 798 ..  NELBO: 7254.6660 .. ARI: 0.5907
# Iter: 799 ..  NELBO: 7254.1958 .. ARI: 0.5878
# Iter: 800 ..  NELBO: 7255.2153 .. ARI: 0.5919
# Iter: 801 ..  NELBO: 7253.7695 .. ARI: 0.5919
# Iter: 802 ..  NELBO: 7254.8096 .. ARI: 0.5932
# Iter: 803 ..  NELBO: 7254.1816 .. ARI: 0.5919
# Iter: 804 ..  NELBO: 7253.7510 .. ARI: 0.5914
# Iter: 805 ..  NELBO: 7253.7886 .. ARI: 0.5914
# Iter: 806 ..  NELBO: 7254.0596 .. ARI: 0.5919
# Iter: 807 ..  NELBO: 7252.6255 .. ARI: 0.5915
# Iter: 808 ..  NELBO: 7253.8696 .. ARI: 0.5915
# Iter: 809 ..  NELBO: 7253.8086 .. ARI: 0.5902
# Iter: 810 ..  NELBO: 7253.4399 .. ARI: 0.5933
# Iter: 811 ..  NELBO: 7252.6685 .. ARI: 0.5908
# Iter: 812 ..  NELBO: 7253.1895 .. ARI: 0.5915
# Iter: 813 ..  NELBO: 7253.7192 .. ARI: 0.5926
# Iter: 814 ..  NELBO: 7253.8867 .. ARI: 0.5915
# Iter: 815 ..  NELBO: 7252.8618 .. ARI: 0.5903
# Iter: 816 ..  NELBO: 7253.0762 .. ARI: 0.5915
# Iter: 817 ..  NELBO: 7252.1138 .. ARI: 0.5915
# Iter: 818 ..  NELBO: 7252.6235 .. ARI: 0.5910
# Iter: 819 ..  NELBO: 7253.0176 .. ARI: 0.5910
# Iter: 820 ..  NELBO: 7251.6943 .. ARI: 0.5915
# Iter: 821 ..  NELBO: 7252.9292 .. ARI: 0.5940
# Iter: 822 ..  NELBO: 7252.3799 .. ARI: 0.5915
# Iter: 823 ..  NELBO: 7251.7173 .. ARI: 0.5927
# Iter: 824 ..  NELBO: 7252.0396 .. ARI: 0.5915
# Iter: 825 ..  NELBO: 7252.1406 .. ARI: 0.5915
# Iter: 826 ..  NELBO: 7252.2715 .. ARI: 0.5915
# Iter: 827 ..  NELBO: 7252.6338 .. ARI: 0.5914
# Iter: 828 ..  NELBO: 7252.2163 .. ARI: 0.5914
# Iter: 829 ..  NELBO: 7252.6924 .. ARI: 0.5939
# Iter: 830 ..  NELBO: 7252.0312 .. ARI: 0.5902
# Iter: 831 ..  NELBO: 7252.0850 .. ARI: 0.5902
# Iter: 832 ..  NELBO: 7251.4229 .. ARI: 0.5939
# Iter: 833 ..  NELBO: 7251.0244 .. ARI: 0.5902
# Iter: 834 ..  NELBO: 7251.2622 .. ARI: 0.5894
# Iter: 835 ..  NELBO: 7252.5166 .. ARI: 0.5932
# Iter: 836 ..  NELBO: 7250.3965 .. ARI: 0.6055
# Iter: 837 ..  NELBO: 7251.5513 .. ARI: 0.5900
# Iter: 838 ..  NELBO: 7251.0195 .. ARI: 0.5935
# Iter: 839 ..  NELBO: 7251.3467 .. ARI: 0.5906
# Iter: 840 ..  NELBO: 7251.3052 .. ARI: 0.5910
# Iter: 841 ..  NELBO: 7251.0098 .. ARI: 0.5910
# Iter: 842 ..  NELBO: 7250.9487 .. ARI: 0.5910
# Iter: 843 ..  NELBO: 7251.3569 .. ARI: 0.5926
# Iter: 844 ..  NELBO: 7250.6489 .. ARI: 0.5919
# Iter: 845 ..  NELBO: 7251.5576 .. ARI: 0.5915
# Iter: 846 ..  NELBO: 7250.7651 .. ARI: 0.5919
# Iter: 847 ..  NELBO: 7250.0029 .. ARI: 0.5919
# Iter: 848 ..  NELBO: 7250.2339 .. ARI: 0.5919
# Iter: 849 ..  NELBO: 7251.0801 .. ARI: 0.5902
# Iter: 850 ..  NELBO: 7250.8843 .. ARI: 0.5914
# Iter: 851 ..  NELBO: 7250.1167 .. ARI: 0.5890
# Iter: 852 ..  NELBO: 7250.4316 .. ARI: 0.5907
# Iter: 853 ..  NELBO: 7250.4536 .. ARI: 0.5903
# Iter: 854 ..  NELBO: 7250.7861 .. ARI: 0.5882
# Iter: 855 ..  NELBO: 7250.0317 .. ARI: 0.5858
# Iter: 856 ..  NELBO: 7249.9219 .. ARI: 0.5910
# Iter: 857 ..  NELBO: 7250.7207 .. ARI: 0.5902
# Iter: 858 ..  NELBO: 7249.2368 .. ARI: 0.5910
# Iter: 859 ..  NELBO: 7250.0059 .. ARI: 0.5910
# Iter: 860 ..  NELBO: 7249.0684 .. ARI: 0.5915
# Iter: 861 ..  NELBO: 7249.1440 .. ARI: 0.5910
# Iter: 862 ..  NELBO: 7250.2300 .. ARI: 0.5915
# Iter: 863 ..  NELBO: 7250.1782 .. ARI: 0.5841
# Iter: 864 ..  NELBO: 7249.1177 .. ARI: 0.5916
# Iter: 865 ..  NELBO: 7249.5562 .. ARI: 0.5873
# Iter: 866 ..  NELBO: 7248.9849 .. ARI: 0.5904
# Iter: 867 ..  NELBO: 7248.9448 .. ARI: 0.5895
# Iter: 868 ..  NELBO: 7249.4048 .. ARI: 0.5908
# Iter: 869 ..  NELBO: 7248.6055 .. ARI: 0.5877
# Iter: 870 ..  NELBO: 7249.1846 .. ARI: 0.5908
# Iter: 871 ..  NELBO: 7248.8315 .. ARI: 0.5867
# Iter: 872 ..  NELBO: 7248.6289 .. ARI: 0.5870
# Iter: 873 ..  NELBO: 7249.0015 .. ARI: 0.5894
# Iter: 874 ..  NELBO: 7248.5967 .. ARI: 0.5908
# Iter: 875 ..  NELBO: 7248.2446 .. ARI: 0.5908
# Iter: 876 ..  NELBO: 7248.0410 .. ARI: 0.5907
# Iter: 877 ..  NELBO: 7248.7500 .. ARI: 0.5895
# Iter: 878 ..  NELBO: 7248.4717 .. ARI: 0.5894
# Iter: 879 ..  NELBO: 7248.6611 .. ARI: 0.5920
# Iter: 880 ..  NELBO: 7247.6069 .. ARI: 0.5891
# Iter: 881 ..  NELBO: 7248.4771 .. ARI: 0.5904
# Iter: 882 ..  NELBO: 7248.8130 .. ARI: 0.5904
# Iter: 883 ..  NELBO: 7248.5303 .. ARI: 0.5904
# Iter: 884 ..  NELBO: 7248.1172 .. ARI: 0.5904
# Iter: 885 ..  NELBO: 7247.9194 .. ARI: 0.5865
# Iter: 886 ..  NELBO: 7248.0713 .. ARI: 0.5879
# Iter: 887 ..  NELBO: 7247.3086 .. ARI: 0.5935
# Iter: 888 ..  NELBO: 7248.3096 .. ARI: 0.5920
# Iter: 889 ..  NELBO: 7248.0908 .. ARI: 0.5913
# Iter: 890 ..  NELBO: 7247.4609 .. ARI: 0.5902
# Iter: 891 ..  NELBO: 7248.2051 .. ARI: 0.5900
# Iter: 892 ..  NELBO: 7246.6279 .. ARI: 0.5887
# Iter: 893 ..  NELBO: 7248.2280 .. ARI: 0.5925
# Iter: 894 ..  NELBO: 7247.8203 .. ARI: 0.5900
# Iter: 895 ..  NELBO: 7246.9229 .. ARI: 0.5907
# Iter: 896 ..  NELBO: 7247.2876 .. ARI: 0.5895
# Iter: 897 ..  NELBO: 7247.2837 .. ARI: 0.5902
# Iter: 898 ..  NELBO: 7247.5244 .. ARI: 0.5890
# Iter: 899 ..  NELBO: 7247.0635 .. ARI: 0.5903
# Iter: 900 ..  NELBO: 7247.4966 .. ARI: 0.5932
# Iter: 901 ..  NELBO: 7247.6284 .. ARI: 0.5919
# Iter: 902 ..  NELBO: 7246.8027 .. ARI: 0.5908
# Iter: 903 ..  NELBO: 7247.5630 .. ARI: 0.5887
# Iter: 904 ..  NELBO: 7247.5703 .. ARI: 0.5887
# Iter: 905 ..  NELBO: 7247.7310 .. ARI: 0.5908
# Iter: 906 ..  NELBO: 7246.9795 .. ARI: 0.5887
# Iter: 907 ..  NELBO: 7247.0498 .. ARI: 0.5874
# Iter: 908 ..  NELBO: 7246.8276 .. ARI: 0.5933
# Iter: 909 ..  NELBO: 7246.0889 .. ARI: 0.5900
# Iter: 910 ..  NELBO: 7246.4893 .. ARI: 0.5871
# Iter: 911 ..  NELBO: 7245.8745 .. ARI: 0.5920
# Iter: 912 ..  NELBO: 7247.3345 .. ARI: 0.5922
# Iter: 913 ..  NELBO: 7247.2202 .. ARI: 0.5927
# Iter: 914 ..  NELBO: 7246.4844 .. ARI: 0.5895
# Iter: 915 ..  NELBO: 7246.2227 .. ARI: 0.6041
# Iter: 916 ..  NELBO: 7245.7944 .. ARI: 0.6012
# Iter: 917 ..  NELBO: 7247.2949 .. ARI: 0.6055
# Iter: 918 ..  NELBO: 7246.3965 .. ARI: 0.5915
# Iter: 919 ..  NELBO: 7245.9087 .. ARI: 0.5892
# Iter: 920 ..  NELBO: 7246.9663 .. ARI: 0.5931
# Iter: 921 ..  NELBO: 7245.5776 .. ARI: 0.5923
# Iter: 922 ..  NELBO: 7245.7124 .. ARI: 0.5888
# Iter: 923 ..  NELBO: 7245.6938 .. ARI: 0.5926
# Iter: 924 ..  NELBO: 7245.8691 .. ARI: 0.5871
# Iter: 925 ..  NELBO: 7246.1641 .. ARI: 0.5925
# Iter: 926 ..  NELBO: 7245.9844 .. ARI: 0.5871
# Iter: 927 ..  NELBO: 7245.7729 .. ARI: 0.5878
# Iter: 928 ..  NELBO: 7245.5708 .. ARI: 0.5925
# Iter: 929 ..  NELBO: 7245.7510 .. ARI: 0.5927
# Iter: 930 ..  NELBO: 7245.9316 .. ARI: 0.5910
# Iter: 931 ..  NELBO: 7245.2808 .. ARI: 0.5853
# Iter: 932 ..  NELBO: 7245.3945 .. ARI: 0.5914
# Iter: 933 ..  NELBO: 7245.4595 .. ARI: 0.5861
# Iter: 934 ..  NELBO: 7245.4575 .. ARI: 0.5895
# Iter: 935 ..  NELBO: 7245.5801 .. ARI: 0.5906
# Iter: 936 ..  NELBO: 7245.1216 .. ARI: 0.6302
# Iter: 937 ..  NELBO: 7245.9297 .. ARI: 0.5883
# Iter: 938 ..  NELBO: 7245.6250 .. ARI: 0.5882
# Iter: 939 ..  NELBO: 7245.3638 .. ARI: 0.5912
# Iter: 940 ..  NELBO: 7245.1006 .. ARI: 0.5845
# Iter: 941 ..  NELBO: 7244.8735 .. ARI: 0.5909
# Iter: 942 ..  NELBO: 7245.1328 .. ARI: 0.5913
# Iter: 943 ..  NELBO: 7244.4985 .. ARI: 0.5909
# Iter: 944 ..  NELBO: 7244.4224 .. ARI: 0.6296
# Iter: 945 ..  NELBO: 7244.8472 .. ARI: 0.6298
# Iter: 946 ..  NELBO: 7244.6328 .. ARI: 0.6292
# Iter: 947 ..  NELBO: 7244.5068 .. ARI: 0.5882
# Iter: 948 ..  NELBO: 7245.2534 .. ARI: 0.6284
# Iter: 949 ..  NELBO: 7244.3042 .. ARI: 0.6265
# Iter: 950 ..  NELBO: 7244.7993 .. ARI: 0.5881
# Iter: 951 ..  NELBO: 7243.8408 .. ARI: 0.5901
# Iter: 952 ..  NELBO: 7243.2666 .. ARI: 0.5899
# Iter: 953 ..  NELBO: 7244.1167 .. ARI: 0.6276
# Iter: 954 ..  NELBO: 7243.8765 .. ARI: 0.5877
# Iter: 955 ..  NELBO: 7244.5220 .. ARI: 0.5877
# Iter: 956 ..  NELBO: 7244.6992 .. ARI: 0.5914
# Iter: 957 ..  NELBO: 7243.3145 .. ARI: 0.5915
# Iter: 958 ..  NELBO: 7243.1436 .. ARI: 0.5919
# Iter: 959 ..  NELBO: 7244.3306 .. ARI: 0.5895
# Iter: 960 ..  NELBO: 7244.8359 .. ARI: 0.5890
# Iter: 961 ..  NELBO: 7244.2002 .. ARI: 0.6278
# Iter: 962 ..  NELBO: 7243.1006 .. ARI: 0.5895
# Iter: 963 ..  NELBO: 7243.8687 .. ARI: 0.5886
# Iter: 964 ..  NELBO: 7243.9502 .. ARI: 0.5920
# Iter: 965 ..  NELBO: 7243.8135 .. ARI: 0.5932
# Iter: 966 ..  NELBO: 7243.0122 .. ARI: 0.5904
# Iter: 967 ..  NELBO: 7243.1147 .. ARI: 0.5933
# Iter: 968 ..  NELBO: 7243.4404 .. ARI: 0.6303
# Iter: 969 ..  NELBO: 7243.3564 .. ARI: 0.5902
# Iter: 970 ..  NELBO: 7243.6621 .. ARI: 0.5942
# Iter: 971 ..  NELBO: 7242.7905 .. ARI: 0.5919
# Iter: 972 ..  NELBO: 7242.9741 .. ARI: 0.5948
# Iter: 973 ..  NELBO: 7242.2954 .. ARI: 0.5869
# Iter: 974 ..  NELBO: 7243.0742 .. ARI: 0.6326
# Iter: 975 ..  NELBO: 7243.4775 .. ARI: 0.5874
# Iter: 976 ..  NELBO: 7242.1240 .. ARI: 0.5862
# Iter: 977 ..  NELBO: 7242.6562 .. ARI: 0.6289
# Iter: 978 ..  NELBO: 7242.4785 .. ARI: 0.6274
# Iter: 979 ..  NELBO: 7242.6011 .. ARI: 0.5924
# Iter: 980 ..  NELBO: 7242.3584 .. ARI: 0.5932
# Iter: 981 ..  NELBO: 7242.5796 .. ARI: 0.5872
# Iter: 982 ..  NELBO: 7242.5630 .. ARI: 0.5887
# Iter: 983 ..  NELBO: 7242.1372 .. ARI: 0.6296
# Iter: 984 ..  NELBO: 7241.8379 .. ARI: 0.5867
# Iter: 985 ..  NELBO: 7242.7314 .. ARI: 0.5870
# Iter: 986 ..  NELBO: 7242.0596 .. ARI: 0.5875
# Iter: 987 ..  NELBO: 7241.4131 .. ARI: 0.5875
# Iter: 988 ..  NELBO: 7241.5894 .. ARI: 0.5869
# Iter: 989 ..  NELBO: 7242.1724 .. ARI: 0.5871
# Iter: 990 ..  NELBO: 7241.6514 .. ARI: 0.5896
# Iter: 991 ..  NELBO: 7241.7456 .. ARI: 0.5858
# Iter: 992 ..  NELBO: 7241.6802 .. ARI: 0.5907
# Iter: 993 ..  NELBO: 7242.4258 .. ARI: 0.5882
# Iter: 994 ..  NELBO: 7241.1475 .. ARI: 0.5882
# Iter: 995 ..  NELBO: 7241.6074 .. ARI: 0.5889
# Iter: 996 ..  NELBO: 7241.3369 .. ARI: 0.5883
# Iter: 997 ..  NELBO: 7242.2729 .. ARI: 0.6281
# Iter: 998 ..  NELBO: 7241.5913 .. ARI: 0.5889
# Iter: 999 ..  NELBO: 7241.5449 .. ARI: 0.6303

# %% [markdown]
# Visualize the training performance

# %%
monitor_perf(scetm_perf, "NELBO")

# %% [markdown]
# # Task 4 (1 point) compare ETM with NMF-Poisson
# Now run NMF-Poisson also for 1000 iterations and compare the ARI scores with scETM over the 1000 iterations. While the NMF model converges to a local optimal after only 200 iterations, the ETM continues to improve. We observe some improvement from ETM over the NMF model especially after 200 iterations. This highlights the benefits of having the non-linear encoder function and perhaps the tri-factorization design in the ETM. When training on massive number of single-cell samples, using SGD on minibatches, ETM may confer bigger improvement. For this particular dataset, with batch-effect correction, a fine-tuned ETM can reach 0.90 ARI (Zhao et al., 2021).

# %%
# YOUR CODE HERE
# Out:
# Iter: 0 .. Loglik: -0.1655 .. ARI: 0.0000
# Iter: 1 .. Loglik: -0.1513 .. ARI: 0.1106
# Iter: 2 .. Loglik: -0.1288 .. ARI: 0.1410
# Iter: 3 .. Loglik: -0.1069 .. ARI: 0.1472
# Iter: 4 .. Loglik: -0.0892 .. ARI: 0.1472
# Iter: 5 .. Loglik: -0.0712 .. ARI: 0.4946
# Iter: 6 .. Loglik: -0.0513 .. ARI: 0.5521
# Iter: 7 .. Loglik: -0.0334 .. ARI: 0.5702
# Iter: 8 .. Loglik: -0.0204 .. ARI: 0.6283
# Iter: 9 .. Loglik: -0.0116 .. ARI: 0.6339
# Iter: 10 .. Loglik: -0.0053 .. ARI: 0.6360
# Iter: 11 .. Loglik: -0.0004 .. ARI: 0.6371
# Iter: 12 .. Loglik: 0.0034 .. ARI: 0.6436
# Iter: 13 .. Loglik: 0.0064 .. ARI: 0.6463
# Iter: 14 .. Loglik: 0.0087 .. ARI: 0.6413
# Iter: 15 .. Loglik: 0.0105 .. ARI: 0.8712
# Iter: 16 .. Loglik: 0.0120 .. ARI: 0.8916
# Iter: 17 .. Loglik: 0.0133 .. ARI: 0.8876
# Iter: 18 .. Loglik: 0.0144 .. ARI: 0.8175
# Iter: 19 .. Loglik: 0.0155 .. ARI: 0.8240
# Iter: 20 .. Loglik: 0.0164 .. ARI: 0.8757
# Iter: 21 .. Loglik: 0.0172 .. ARI: 0.8681
# Iter: 22 .. Loglik: 0.0180 .. ARI: 0.8701
# Iter: 23 .. Loglik: 0.0187 .. ARI: 0.8654
# Iter: 24 .. Loglik: 0.0193 .. ARI: 0.8731
# Iter: 25 .. Loglik: 0.0199 .. ARI: 0.8668
# Iter: 26 .. Loglik: 0.0205 .. ARI: 0.8543
# Iter: 27 .. Loglik: 0.0210 .. ARI: 0.8501
# Iter: 28 .. Loglik: 0.0214 .. ARI: 0.8265
# Iter: 29 .. Loglik: 0.0219 .. ARI: 0.8252
# Iter: 30 .. Loglik: 0.0223 .. ARI: 0.8595
# Iter: 31 .. Loglik: 0.0226 .. ARI: 0.8263
# Iter: 32 .. Loglik: 0.0230 .. ARI: 0.8307
# Iter: 33 .. Loglik: 0.0233 .. ARI: 0.8561
# Iter: 34 .. Loglik: 0.0237 .. ARI: 0.8283
# Iter: 35 .. Loglik: 0.0240 .. ARI: 0.8447
# Iter: 36 .. Loglik: 0.0242 .. ARI: 0.5814
# Iter: 37 .. Loglik: 0.0244 .. ARI: 0.6067
# Iter: 38 .. Loglik: 0.0246 .. ARI: 0.5850
# Iter: 39 .. Loglik: 0.0248 .. ARI: 0.6046
# Iter: 40 .. Loglik: 0.0250 .. ARI: 0.6088
# Iter: 41 .. Loglik: 0.0251 .. ARI: 0.6068
# Iter: 42 .. Loglik: 0.0252 .. ARI: 0.6009
# Iter: 43 .. Loglik: 0.0254 .. ARI: 0.6112
# Iter: 44 .. Loglik: 0.0255 .. ARI: 0.6017
# Iter: 45 .. Loglik: 0.0256 .. ARI: 0.6028
# Iter: 46 .. Loglik: 0.0257 .. ARI: 0.6014
# Iter: 47 .. Loglik: 0.0258 .. ARI: 0.6058
# Iter: 48 .. Loglik: 0.0259 .. ARI: 0.5979
# Iter: 49 .. Loglik: 0.0260 .. ARI: 0.6123
# Iter: 50 .. Loglik: 0.0260 .. ARI: 0.5996
# Iter: 51 .. Loglik: 0.0261 .. ARI: 0.6001
# Iter: 52 .. Loglik: 0.0262 .. ARI: 0.6049
# Iter: 53 .. Loglik: 0.0263 .. ARI: 0.5947
# Iter: 54 .. Loglik: 0.0263 .. ARI: 0.5958
# Iter: 55 .. Loglik: 0.0264 .. ARI: 0.6008
# Iter: 56 .. Loglik: 0.0264 .. ARI: 0.6180
# Iter: 57 .. Loglik: 0.0265 .. ARI: 0.6174
# Iter: 58 .. Loglik: 0.0265 .. ARI: 0.5295
# Iter: 59 .. Loglik: 0.0266 .. ARI: 0.6152
# Iter: 60 .. Loglik: 0.0266 .. ARI: 0.6166
# Iter: 61 .. Loglik: 0.0267 .. ARI: 0.5220
# Iter: 62 .. Loglik: 0.0267 .. ARI: 0.8550
# Iter: 63 .. Loglik: 0.0267 .. ARI: 0.6206
# Iter: 64 .. Loglik: 0.0268 .. ARI: 0.6168
# Iter: 65 .. Loglik: 0.0268 .. ARI: 0.6081
# Iter: 66 .. Loglik: 0.0269 .. ARI: 0.6076
# Iter: 67 .. Loglik: 0.0269 .. ARI: 0.6032
# Iter: 68 .. Loglik: 0.0269 .. ARI: 0.6148
# Iter: 69 .. Loglik: 0.0269 .. ARI: 0.6143
# Iter: 70 .. Loglik: 0.0270 .. ARI: 0.6145
# Iter: 71 .. Loglik: 0.0270 .. ARI: 0.6155
# Iter: 72 .. Loglik: 0.0270 .. ARI: 0.6145
# Iter: 73 .. Loglik: 0.0271 .. ARI: 0.6150
# Iter: 74 .. Loglik: 0.0271 .. ARI: 0.5354
# Iter: 75 .. Loglik: 0.0271 .. ARI: 0.6165
# Iter: 76 .. Loglik: 0.0271 .. ARI: 0.4726
# Iter: 77 .. Loglik: 0.0272 .. ARI: 0.5258
# Iter: 78 .. Loglik: 0.0272 .. ARI: 0.6174
# Iter: 79 .. Loglik: 0.0272 .. ARI: 0.6185
# Iter: 80 .. Loglik: 0.0272 .. ARI: 0.5249
# Iter: 81 .. Loglik: 0.0272 .. ARI: 0.6055
# Iter: 82 .. Loglik: 0.0273 .. ARI: 0.5243
# Iter: 83 .. Loglik: 0.0273 .. ARI: 0.6181
# Iter: 84 .. Loglik: 0.0273 .. ARI: 0.6165
# Iter: 85 .. Loglik: 0.0273 .. ARI: 0.5491
# Iter: 86 .. Loglik: 0.0273 .. ARI: 0.5467
# Iter: 87 .. Loglik: 0.0273 .. ARI: 0.6043
# Iter: 88 .. Loglik: 0.0274 .. ARI: 0.6181
# Iter: 89 .. Loglik: 0.0274 .. ARI: 0.6181
# Iter: 90 .. Loglik: 0.0274 .. ARI: 0.4869
# Iter: 91 .. Loglik: 0.0274 .. ARI: 0.5824
# Iter: 92 .. Loglik: 0.0274 .. ARI: 0.6149
# Iter: 93 .. Loglik: 0.0274 .. ARI: 0.5827
# Iter: 94 .. Loglik: 0.0274 .. ARI: 0.5839
# Iter: 95 .. Loglik: 0.0275 .. ARI: 0.5831
# Iter: 96 .. Loglik: 0.0275 .. ARI: 0.5832
# Iter: 97 .. Loglik: 0.0275 .. ARI: 0.6175
# Iter: 98 .. Loglik: 0.0275 .. ARI: 0.6058
# Iter: 99 .. Loglik: 0.0275 .. ARI: 0.6069
# Iter: 100 .. Loglik: 0.0275 .. ARI: 0.5857
# Iter: 101 .. Loglik: 0.0275 .. ARI: 0.6069
# Iter: 102 .. Loglik: 0.0275 .. ARI: 0.5857
# Iter: 103 .. Loglik: 0.0275 .. ARI: 0.6069
# Iter: 104 .. Loglik: 0.0276 .. ARI: 0.6051
# Iter: 105 .. Loglik: 0.0276 .. ARI: 0.6051
# Iter: 106 .. Loglik: 0.0276 .. ARI: 0.6063
# Iter: 107 .. Loglik: 0.0276 .. ARI: 0.5827
# Iter: 108 .. Loglik: 0.0276 .. ARI: 0.5815
# Iter: 109 .. Loglik: 0.0276 .. ARI: 0.5469
# Iter: 110 .. Loglik: 0.0276 .. ARI: 0.5473
# Iter: 111 .. Loglik: 0.0276 .. ARI: 0.5475
# Iter: 112 .. Loglik: 0.0276 .. ARI: 0.5486
# Iter: 113 .. Loglik: 0.0276 .. ARI: 0.5475
# Iter: 114 .. Loglik: 0.0276 .. ARI: 0.5475
# Iter: 115 .. Loglik: 0.0276 .. ARI: 0.5484
# Iter: 116 .. Loglik: 0.0276 .. ARI: 0.5843
# Iter: 117 .. Loglik: 0.0276 .. ARI: 0.6043
# Iter: 118 .. Loglik: 0.0276 .. ARI: 0.6155
# Iter: 119 .. Loglik: 0.0276 .. ARI: 0.6043
# Iter: 120 .. Loglik: 0.0277 .. ARI: 0.6043
# Iter: 121 .. Loglik: 0.0277 .. ARI: 0.6140
# Iter: 122 .. Loglik: 0.0277 .. ARI: 0.6027
# Iter: 123 .. Loglik: 0.0277 .. ARI: 0.6047
# Iter: 124 .. Loglik: 0.0277 .. ARI: 0.6043
# Iter: 125 .. Loglik: 0.0277 .. ARI: 0.6167
# Iter: 126 .. Loglik: 0.0277 .. ARI: 0.6155
# Iter: 127 .. Loglik: 0.0277 .. ARI: 0.6043
# Iter: 128 .. Loglik: 0.0277 .. ARI: 0.6043
# Iter: 129 .. Loglik: 0.0277 .. ARI: 0.6167
# Iter: 130 .. Loglik: 0.0277 .. ARI: 0.6167
# Iter: 131 .. Loglik: 0.0277 .. ARI: 0.6155
# Iter: 132 .. Loglik: 0.0277 .. ARI: 0.6043
# Iter: 133 .. Loglik: 0.0277 .. ARI: 0.6055
# Iter: 134 .. Loglik: 0.0277 .. ARI: 0.6055
# Iter: 135 .. Loglik: 0.0277 .. ARI: 0.6058
# Iter: 136 .. Loglik: 0.0277 .. ARI: 0.6061
# Iter: 137 .. Loglik: 0.0277 .. ARI: 0.6043
# Iter: 138 .. Loglik: 0.0277 .. ARI: 0.6023
# Iter: 139 .. Loglik: 0.0277 .. ARI: 0.6028
# Iter: 140 .. Loglik: 0.0278 .. ARI: 0.6017
# Iter: 141 .. Loglik: 0.0278 .. ARI: 0.6017
# Iter: 142 .. Loglik: 0.0278 .. ARI: 0.6055
# Iter: 143 .. Loglik: 0.0278 .. ARI: 0.6026
# Iter: 144 .. Loglik: 0.0278 .. ARI: 0.6034
# Iter: 145 .. Loglik: 0.0278 .. ARI: 0.6046
# Iter: 146 .. Loglik: 0.0278 .. ARI: 0.6046
# Iter: 147 .. Loglik: 0.0278 .. ARI: 0.6039
# Iter: 148 .. Loglik: 0.0278 .. ARI: 0.6045
# Iter: 149 .. Loglik: 0.0278 .. ARI: 0.6036
# Iter: 150 .. Loglik: 0.0278 .. ARI: 0.6031
# Iter: 151 .. Loglik: 0.0278 .. ARI: 0.6027
# Iter: 152 .. Loglik: 0.0278 .. ARI: 0.6027
# Iter: 153 .. Loglik: 0.0278 .. ARI: 0.6035
# Iter: 154 .. Loglik: 0.0278 .. ARI: 0.6035
# Iter: 155 .. Loglik: 0.0278 .. ARI: 0.6035
# Iter: 156 .. Loglik: 0.0278 .. ARI: 0.6035
# Iter: 157 .. Loglik: 0.0279 .. ARI: 0.6035
# Iter: 158 .. Loglik: 0.0279 .. ARI: 0.6034
# Iter: 159 .. Loglik: 0.0279 .. ARI: 0.6050
# Iter: 160 .. Loglik: 0.0279 .. ARI: 0.6050
# Iter: 161 .. Loglik: 0.0279 .. ARI: 0.6042
# Iter: 162 .. Loglik: 0.0279 .. ARI: 0.6042
# Iter: 163 .. Loglik: 0.0279 .. ARI: 0.6034
# Iter: 164 .. Loglik: 0.0279 .. ARI: 0.6042
# Iter: 165 .. Loglik: 0.0279 .. ARI: 0.6042
# Iter: 166 .. Loglik: 0.0279 .. ARI: 0.6042
# Iter: 167 .. Loglik: 0.0279 .. ARI: 0.6059
# Iter: 168 .. Loglik: 0.0279 .. ARI: 0.5849
# Iter: 169 .. Loglik: 0.0279 .. ARI: 0.6052
# Iter: 170 .. Loglik: 0.0279 .. ARI: 0.6052
# Iter: 171 .. Loglik: 0.0279 .. ARI: 0.6052
# Iter: 172 .. Loglik: 0.0279 .. ARI: 0.6052
# Iter: 173 .. Loglik: 0.0279 .. ARI: 0.6052
# Iter: 174 .. Loglik: 0.0279 .. ARI: 0.5910
# Iter: 175 .. Loglik: 0.0279 .. ARI: 0.6052
# Iter: 176 .. Loglik: 0.0279 .. ARI: 0.5910
# Iter: 177 .. Loglik: 0.0279 .. ARI: 0.5744
# Iter: 178 .. Loglik: 0.0279 .. ARI: 0.5744
# Iter: 179 .. Loglik: 0.0279 .. ARI: 0.5739
# Iter: 180 .. Loglik: 0.0279 .. ARI: 0.6048
# Iter: 181 .. Loglik: 0.0279 .. ARI: 0.5739
# Iter: 182 .. Loglik: 0.0279 .. ARI: 0.6048
# Iter: 183 .. Loglik: 0.0279 .. ARI: 0.5742
# Iter: 184 .. Loglik: 0.0279 .. ARI: 0.6048
# Iter: 185 .. Loglik: 0.0279 .. ARI: 0.6048
# Iter: 186 .. Loglik: 0.0279 .. ARI: 0.6048
# Iter: 187 .. Loglik: 0.0279 .. ARI: 0.6040
# Iter: 188 .. Loglik: 0.0279 .. ARI: 0.6052
# Iter: 189 .. Loglik: 0.0279 .. ARI: 0.6040
# Iter: 190 .. Loglik: 0.0279 .. ARI: 0.6040
# Iter: 191 .. Loglik: 0.0279 .. ARI: 0.6040
# Iter: 192 .. Loglik: 0.0279 .. ARI: 0.6052
# Iter: 193 .. Loglik: 0.0279 .. ARI: 0.6052
# Iter: 194 .. Loglik: 0.0279 .. ARI: 0.6052
# Iter: 195 .. Loglik: 0.0279 .. ARI: 0.6052
# Iter: 196 .. Loglik: 0.0279 .. ARI: 0.6052
# Iter: 197 .. Loglik: 0.0279 .. ARI: 0.6052
# Iter: 198 .. Loglik: 0.0279 .. ARI: 0.6040
# Iter: 199 .. Loglik: 0.0279 .. ARI: 0.6040
# Iter: 200 .. Loglik: 0.0279 .. ARI: 0.6040
# Iter: 201 .. Loglik: 0.0279 .. ARI: 0.6040
# Iter: 202 .. Loglik: 0.0279 .. ARI: 0.6040
# Iter: 203 .. Loglik: 0.0279 .. ARI: 0.6040
# Iter: 204 .. Loglik: 0.0279 .. ARI: 0.6040
# Iter: 205 .. Loglik: 0.0279 .. ARI: 0.6040
# Iter: 206 .. Loglik: 0.0279 .. ARI: 0.6045
# Iter: 207 .. Loglik: 0.0279 .. ARI: 0.6045
# Iter: 208 .. Loglik: 0.0279 .. ARI: 0.6045
# Iter: 209 .. Loglik: 0.0279 .. ARI: 0.6045
# Iter: 210 .. Loglik: 0.0279 .. ARI: 0.6045
# Iter: 211 .. Loglik: 0.0279 .. ARI: 0.6045
# Iter: 212 .. Loglik: 0.0279 .. ARI: 0.6045
# Iter: 213 .. Loglik: 0.0279 .. ARI: 0.6045
# Iter: 214 .. Loglik: 0.0279 .. ARI: 0.6045
# Iter: 215 .. Loglik: 0.0279 .. ARI: 0.6045
# Iter: 216 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 217 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 218 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 219 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 220 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 221 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 222 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 223 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 224 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 225 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 226 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 227 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 228 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 229 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 230 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 231 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 232 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 233 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 234 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 235 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 236 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 237 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 238 .. Loglik: 0.0280 .. ARI: 0.6041
# Iter: 239 .. Loglik: 0.0280 .. ARI: 0.6041
# Iter: 240 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 241 .. Loglik: 0.0280 .. ARI: 0.6041
# Iter: 242 .. Loglik: 0.0280 .. ARI: 0.6041
# Iter: 243 .. Loglik: 0.0280 .. ARI: 0.6042
# Iter: 244 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 245 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 246 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 247 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 248 .. Loglik: 0.0280 .. ARI: 0.6053
# Iter: 249 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 250 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 251 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 252 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 253 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 254 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 255 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 256 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 257 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 258 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 259 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 260 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 261 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 262 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 263 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 264 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 265 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 266 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 267 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 268 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 269 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 270 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 271 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 272 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 273 .. Loglik: 0.0280 .. ARI: 0.6010
# Iter: 274 .. Loglik: 0.0280 .. ARI: 0.6010
# Iter: 275 .. Loglik: 0.0280 .. ARI: 0.6010
# Iter: 276 .. Loglik: 0.0280 .. ARI: 0.6010
# Iter: 277 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 278 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 279 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 280 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 281 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 282 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 283 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 284 .. Loglik: 0.0280 .. ARI: 0.6045
# Iter: 285 .. Loglik: 0.0280 .. ARI: 0.6021
# Iter: 286 .. Loglik: 0.0280 .. ARI: 0.6010
# Iter: 287 .. Loglik: 0.0280 .. ARI: 0.6010
# Iter: 288 .. Loglik: 0.0280 .. ARI: 0.6010
# Iter: 289 .. Loglik: 0.0280 .. ARI: 0.6010
# Iter: 290 .. Loglik: 0.0280 .. ARI: 0.6034
# Iter: 291 .. Loglik: 0.0280 .. ARI: 0.6034
# Iter: 292 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 293 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 294 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 295 .. Loglik: 0.0280 .. ARI: 0.6034
# Iter: 296 .. Loglik: 0.0280 .. ARI: 0.6039
# Iter: 297 .. Loglik: 0.0280 .. ARI: 0.6039
# Iter: 298 .. Loglik: 0.0280 .. ARI: 0.6039
# Iter: 299 .. Loglik: 0.0280 .. ARI: 0.6039
# Iter: 300 .. Loglik: 0.0280 .. ARI: 0.6034
# Iter: 301 .. Loglik: 0.0280 .. ARI: 0.6034
# Iter: 302 .. Loglik: 0.0280 .. ARI: 0.6034
# Iter: 303 .. Loglik: 0.0280 .. ARI: 0.6010
# Iter: 304 .. Loglik: 0.0280 .. ARI: 0.6010
# Iter: 305 .. Loglik: 0.0280 .. ARI: 0.6034
# Iter: 306 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 307 .. Loglik: 0.0280 .. ARI: 0.6039
# Iter: 308 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 309 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 310 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 311 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 312 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 313 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 314 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 315 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 316 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 317 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 318 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 319 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 320 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 321 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 322 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 323 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 324 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 325 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 326 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 327 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 328 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 329 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 330 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 331 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 332 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 333 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 334 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 335 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 336 .. Loglik: 0.0280 .. ARI: 0.6050
# Iter: 337 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 338 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 339 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 340 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 341 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 342 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 343 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 344 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 345 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 346 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 347 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 348 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 349 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 350 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 351 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 352 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 353 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 354 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 355 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 356 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 357 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 358 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 359 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 360 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 361 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 362 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 363 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 364 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 365 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 366 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 367 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 368 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 369 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 370 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 371 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 372 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 373 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 374 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 375 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 376 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 377 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 378 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 379 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 380 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 381 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 382 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 383 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 384 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 385 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 386 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 387 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 388 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 389 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 390 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 391 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 392 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 393 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 394 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 395 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 396 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 397 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 398 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 399 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 400 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 401 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 402 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 403 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 404 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 405 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 406 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 407 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 408 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 409 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 410 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 411 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 412 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 413 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 414 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 415 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 416 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 417 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 418 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 419 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 420 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 421 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 422 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 423 .. Loglik: 0.0280 .. ARI: 0.6065
# Iter: 424 .. Loglik: 0.0280 .. ARI: 0.6065
# Iter: 425 .. Loglik: 0.0280 .. ARI: 0.6065
# Iter: 426 .. Loglik: 0.0280 .. ARI: 0.6065
# Iter: 427 .. Loglik: 0.0280 .. ARI: 0.6065
# Iter: 428 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 429 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 430 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 431 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 432 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 433 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 434 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 435 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 436 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 437 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 438 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 439 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 440 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 441 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 442 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 443 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 444 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 445 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 446 .. Loglik: 0.0280 .. ARI: 0.6057
# Iter: 447 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 448 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 449 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 450 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 451 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 452 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 453 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 454 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 455 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 456 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 457 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 458 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 459 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 460 .. Loglik: 0.0280 .. ARI: 0.6046
# Iter: 461 .. Loglik: 0.0280 .. ARI: 0.6043
# Iter: 462 .. Loglik: 0.0280 .. ARI: 0.6043
# Iter: 463 .. Loglik: 0.0280 .. ARI: 0.6043
# Iter: 464 .. Loglik: 0.0280 .. ARI: 0.6043
# Iter: 465 .. Loglik: 0.0280 .. ARI: 0.6043
# Iter: 466 .. Loglik: 0.0280 .. ARI: 0.6043
# Iter: 467 .. Loglik: 0.0280 .. ARI: 0.6043
# Iter: 468 .. Loglik: 0.0280 .. ARI: 0.6043
# Iter: 469 .. Loglik: 0.0280 .. ARI: 0.6043
# Iter: 470 .. Loglik: 0.0280 .. ARI: 0.6043
# Iter: 471 .. Loglik: 0.0280 .. ARI: 0.6043
# Iter: 472 .. Loglik: 0.0280 .. ARI: 0.6043
# Iter: 473 .. Loglik: 0.0280 .. ARI: 0.6043
# Iter: 474 .. Loglik: 0.0280 .. ARI: 0.6035
# Iter: 475 .. Loglik: 0.0280 .. ARI: 0.6035
# Iter: 476 .. Loglik: 0.0280 .. ARI: 0.6035
# Iter: 477 .. Loglik: 0.0280 .. ARI: 0.6035
# Iter: 478 .. Loglik: 0.0280 .. ARI: 0.6035
# Iter: 479 .. Loglik: 0.0280 .. ARI: 0.6035
# Iter: 480 .. Loglik: 0.0280 .. ARI: 0.6035
# Iter: 481 .. Loglik: 0.0280 .. ARI: 0.6035
# Iter: 482 .. Loglik: 0.0280 .. ARI: 0.6035
# Iter: 483 .. Loglik: 0.0280 .. ARI: 0.6035
# Iter: 484 .. Loglik: 0.0280 .. ARI: 0.6035
# Iter: 485 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 486 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 487 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 488 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 489 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 490 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 491 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 492 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 493 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 494 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 495 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 496 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 497 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 498 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 499 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 500 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 501 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 502 .. Loglik: 0.0280 .. ARI: 0.6058
# Iter: 503 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 504 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 505 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 506 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 507 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 508 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 509 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 510 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 511 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 512 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 513 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 514 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 515 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 516 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 517 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 518 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 519 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 520 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 521 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 522 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 523 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 524 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 525 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 526 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 527 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 528 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 529 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 530 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 531 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 532 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 533 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 534 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 535 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 536 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 537 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 538 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 539 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 540 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 541 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 542 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 543 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 544 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 545 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 546 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 547 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 548 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 549 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 550 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 551 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 552 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 553 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 554 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 555 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 556 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 557 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 558 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 559 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 560 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 561 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 562 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 563 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 564 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 565 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 566 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 567 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 568 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 569 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 570 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 571 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 572 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 573 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 574 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 575 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 576 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 577 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 578 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 579 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 580 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 581 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 582 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 583 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 584 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 585 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 586 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 587 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 588 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 589 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 590 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 591 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 592 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 593 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 594 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 595 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 596 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 597 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 598 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 599 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 600 .. Loglik: 0.0280 .. ARI: 0.6068
# Iter: 601 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 602 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 603 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 604 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 605 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 606 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 607 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 608 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 609 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 610 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 611 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 612 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 613 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 614 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 615 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 616 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 617 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 618 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 619 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 620 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 621 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 622 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 623 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 624 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 625 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 626 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 627 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 628 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 629 .. Loglik: 0.0280 .. ARI: 0.6061
# Iter: 630 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 631 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 632 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 633 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 634 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 635 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 636 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 637 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 638 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 639 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 640 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 641 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 642 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 643 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 644 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 645 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 646 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 647 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 648 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 649 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 650 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 651 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 652 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 653 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 654 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 655 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 656 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 657 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 658 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 659 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 660 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 661 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 662 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 663 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 664 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 665 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 666 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 667 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 668 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 669 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 670 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 671 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 672 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 673 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 674 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 675 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 676 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 677 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 678 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 679 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 680 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 681 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 682 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 683 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 684 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 685 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 686 .. Loglik: 0.0281 .. ARI: 0.6061
# Iter: 687 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 688 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 689 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 690 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 691 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 692 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 693 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 694 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 695 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 696 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 697 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 698 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 699 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 700 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 701 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 702 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 703 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 704 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 705 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 706 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 707 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 708 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 709 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 710 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 711 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 712 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 713 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 714 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 715 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 716 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 717 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 718 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 719 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 720 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 721 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 722 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 723 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 724 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 725 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 726 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 727 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 728 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 729 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 730 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 731 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 732 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 733 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 734 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 735 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 736 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 737 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 738 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 739 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 740 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 741 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 742 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 743 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 744 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 745 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 746 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 747 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 748 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 749 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 750 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 751 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 752 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 753 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 754 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 755 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 756 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 757 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 758 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 759 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 760 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 761 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 762 .. Loglik: 0.0281 .. ARI: 0.6058
# Iter: 763 .. Loglik: 0.0281 .. ARI: 0.6053
# Iter: 764 .. Loglik: 0.0281 .. ARI: 0.6053
# Iter: 765 .. Loglik: 0.0281 .. ARI: 0.6053
# Iter: 766 .. Loglik: 0.0281 .. ARI: 0.6053
# Iter: 767 .. Loglik: 0.0281 .. ARI: 0.6053
# Iter: 768 .. Loglik: 0.0281 .. ARI: 0.6053
# Iter: 769 .. Loglik: 0.0281 .. ARI: 0.6053
# Iter: 770 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 771 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 772 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 773 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 774 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 775 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 776 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 777 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 778 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 779 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 780 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 781 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 782 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 783 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 784 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 785 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 786 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 787 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 788 .. Loglik: 0.0281 .. ARI: 0.6057
# Iter: 789 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 790 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 791 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 792 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 793 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 794 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 795 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 796 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 797 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 798 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 799 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 800 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 801 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 802 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 803 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 804 .. Loglik: 0.0281 .. ARI: 0.6062
# Iter: 805 .. Loglik: 0.0281 .. ARI: 0.6068
# Iter: 806 .. Loglik: 0.0281 .. ARI: 0.6068
# Iter: 807 .. Loglik: 0.0281 .. ARI: 0.6068
# Iter: 808 .. Loglik: 0.0281 .. ARI: 0.6068
# Iter: 809 .. Loglik: 0.0281 .. ARI: 0.6068
# Iter: 810 .. Loglik: 0.0281 .. ARI: 0.6068
# Iter: 811 .. Loglik: 0.0281 .. ARI: 0.6068
# Iter: 812 .. Loglik: 0.0281 .. ARI: 0.6068
# Iter: 813 .. Loglik: 0.0281 .. ARI: 0.6068
# Iter: 814 .. Loglik: 0.0281 .. ARI: 0.6068
# Iter: 815 .. Loglik: 0.0281 .. ARI: 0.6068
# Iter: 816 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 817 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 818 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 819 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 820 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 821 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 822 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 823 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 824 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 825 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 826 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 827 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 828 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 829 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 830 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 831 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 832 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 833 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 834 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 835 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 836 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 837 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 838 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 839 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 840 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 841 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 842 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 843 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 844 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 845 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 846 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 847 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 848 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 849 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 850 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 851 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 852 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 853 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 854 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 855 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 856 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 857 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 858 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 859 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 860 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 861 .. Loglik: 0.0281 .. ARI: 0.6080
# Iter: 862 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 863 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 864 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 865 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 866 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 867 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 868 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 869 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 870 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 871 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 872 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 873 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 874 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 875 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 876 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 877 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 878 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 879 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 880 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 881 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 882 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 883 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 884 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 885 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 886 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 887 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 888 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 889 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 890 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 891 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 892 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 893 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 894 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 895 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 896 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 897 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 898 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 899 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 900 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 901 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 902 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 903 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 904 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 905 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 906 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 907 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 908 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 909 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 910 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 911 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 912 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 913 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 914 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 915 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 916 .. Loglik: 0.0281 .. ARI: 0.6076
# Iter: 917 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 918 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 919 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 920 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 921 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 922 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 923 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 924 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 925 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 926 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 927 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 928 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 929 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 930 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 931 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 932 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 933 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 934 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 935 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 936 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 937 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 938 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 939 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 940 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 941 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 942 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 943 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 944 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 945 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 946 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 947 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 948 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 949 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 950 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 951 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 952 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 953 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 954 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 955 .. Loglik: 0.0281 .. ARI: 0.6069
# Iter: 956 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 957 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 958 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 959 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 960 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 961 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 962 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 963 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 964 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 965 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 966 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 967 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 968 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 969 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 970 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 971 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 972 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 973 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 974 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 975 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 976 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 977 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 978 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 979 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 980 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 981 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 982 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 983 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 984 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 985 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 986 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 987 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 988 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 989 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 990 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 991 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 992 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 993 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 994 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 995 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 996 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 997 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 998 .. Loglik: 0.0281 .. ARI: 0.6065
# Iter: 999 .. Loglik: 0.0281 .. ARI: 0.6065

# %% [markdown]
# # Task 5 (1 point) Generate t-SNE to visualize cell embeddings
# Use the `model` object of ETM saved from the previous training over the 1000 iterations to infer final cell topic embedding $\mathbf{\theta}$ and generate the two-dimensional t-SNE plot. Also, use the `H` matrix from the NMF-Poisson model (trained after 1000 iterations) to generate another two-dimensional t-SNE plot. Compare them side-by-side as shown in plots below, respectively. We observe a slightly better separation of the alpha cells from other cells from the ETM compared to the NMF-Poisson model.
#
# The plot was generated using a `Scanpy` function called `sc.tl.tsne`. Learn how to use it from its documentation.

# %%
# YOUR CODE HERE
# Out:
# /Users/yueli/anaconda3/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /Users/yueli/anaconda3/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # Task 6 (1 point) Plot heatmap for the cells under each topic
# An alternative way to present the cell cluster is by heatmap. Heatmap is more effective in identifying which topics correlates well with which cell types. Generate a heatmap plot for the same cells-by-topics matrix $\mathbf{\theta}$ using *all of the 1886 cells over the 16 topics*. Your heatmap should look similar to the plot below, which was generated using `seaborn.clustermap`.
#
# From here, we see that topic 7 correlates well with alpha cell type, topic 2 with endothelial, topic 6 with ductal cell type, and so forth. Note that you will get different topic indices matching with different cell types as the order of these topics are not the same at different runs.

# %%
# YOUR CODE HERE
# Out:
# /Users/yueli/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /Users/yueli/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %% [markdown]
# # Task 7 (1 point) Plot heatmap for the top genes under each topic
# To get cell-type-specific gene signature, we can visualize the genes by topics heatmap. Here we will plot the top 5 genes per topic in heatmap. Your heatmap should look similar to one below, which was generated using `seaborn.heatmap`. In plotting the heatmap, I capped the max value at 0.2 instead of letting it set to 1 to make the red intensities more prominent for some of the genes with low absolute value under some of the topics.
#
# What cell-type-specific gene signatures can you find in your analysis? For example, from the heatmap we know that topic 7 corresponds to alpha cell type. The gene *Gcg*, which codes for protein Glucagon has the highest probability under that topic. Based on https://www.proteinatlas.org/ENSG00000115263-GCG, Glucagon is indeed a pancreatic hormone that counteracts the glucose-lowering action of insulin by stimulating glycogenolysis and gluconeogenesis!

# %%
# YOUR CODE HERE
